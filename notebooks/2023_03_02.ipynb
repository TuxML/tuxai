# %%
import os
os.chdir("..")

from pprint import pprint
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from tuxai.dataset import Dataset, Columns
from tuxai.misc import config_logger, get_config
# from tuxai.report import model_metrics, Report, FeatureImportanceReport

config_logger()
pd.options.display.max_rows = 300
pd.options.display.max_colwidth = 100

# %% [markdown]
# # What is the best compressed target (lower size)

# %%
d = {version: Dataset(version).get_dataframe(Columns.targets).mean().sort_values().head(1) for version in get_config()["report"]["versions"]}
pprint(d)
# Out:
# {413: XZ    6.171931
# dtype: float64,
#  415: XZ    8.538569
# dtype: float64,
#  420: XZ    8.567795
# dtype: float64,
#  500: XZ    8.897627
# dtype: float64,
#  504: XZ    11.160873
# dtype: float64,
#  507: XZ    11.165376
# dtype: float64,
#  508: XZ    9.813614
# dtype: float64}

# %%
Dataset(413).get_dataframe(Columns.targets).mean().sort_values()
# Out:
# XZ                6.171931
# XZ-bzImage        6.321029
# LZMA              6.765994
# LZMA-bzImage      6.906686
# BZIP2             8.198103
# XZ-vmlinux        8.309487
# GZIP              8.456118
# GZIP-bzImage      8.606845
# LZMA-vmlinux      8.894736
# LZO               9.403426
# LZO-bzImage       9.541922
# LZ4              10.084096
# LZ4-bzImage      10.234466
# GZIP-vmlinux     10.595388
# LZO-vmlinux      11.529966
# LZ4-vmlinux      12.222827
# BZIP2-bzImage    12.274483
# BZIP2-vmlinux    14.255325
# vmlinux          47.334369
# dtype: float64

# %% [markdown]
# # Overview report

# %%
from tuxai.report import OverviewReport
ovr = OverviewReport(fir_cache="fi_const_2023")
# Out:
# 2023-02-28 11:46:51,472 :: INFO :: tuxai.report :: loading feature importance data from cache: fi_const_2023
#   0%|          | 0/12369 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# 2023-02-28 11:48:34,137 :: INFO :: tuxai.report :: loading feature importance data from cache: fi_const_2023
#   0%|          | 0/12369 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]

# %%
ovr._ranks_and_yes_frequencies["vmlinux"]
# Out:
#                            4.13  4.15  4.20  5.00   5.04   5.07   5.08  \
# UBSAN_ALIGNMENT               8     8     7     8      9      9      9
# PINCTRL                    8432  8526  9176  9311   9700  10168  10340
# PINMUX                     5686   704  6392  6458   6732   7102   7160
# CEC_NOTIFIER               4736  4895  5381  5469    506   5857   5978
# VIDEO_V4L2_SUBDEV_API      5979  6132  6043  6114   7052   7448   7480
# PM_OPP                     6756  6884  7494   836   7196   8322   8414
# RPMSG                       492  5823  6317  6436   6651   7037   7099
# CRYPTO_SEQIV               5087  5229  5751  5817   5902   6245   6394
# PRIME_NUMBERS               216   107   792   783    853   5101   5102
# MEDIA_CONTROLLER           8458  8628  9335   468   9815  10335  10527
# GCC_PLUGIN_RANDSTRUCT       291   171  3717  1915   3694   4003   3933
# GCC_PLUGIN_LATENT_ENTROPY  1382   133  5611  5683   1282   1982   6241
# GPIO_MB86S7X               1854  3279  2382  3705   2363   1995   1906
# INTEL_SOC_DTS_IOSF_CORE    7458  1678  8172  8265   8684   9115   2044
# PINCTRL_AMD                2529  2736  3079  3145   3137   3296   3323
# HID_WACOM                  1438  4620  5760  2063   5920   6258   6413
# PINCTRL_MCP23S08            507  4977  5606  5678   5860    628   6234
# PINCTRL_PXA                4844  4990   783  5572   5647   5992   6118
# DEBUG_PINCTRL               976  6557  7133  7218   7519   1472   1285
# MFD_TPS65217               1290  2961  3321  3380   3346   3552   3520
# HID_ASUS                   2787  3109  3472  3518   3419    362   3667
# MFD_TPS65218               1289  7455  8082  8168   8720   9176   9284
# RC_CORE                    8780  8828  9549  9686  10172  10576  10762
# GPIO_ACPI                  2231   164  2793   323   1335    161    390
# SERIO_OLPC_APSP            4105  4277  4699  1079   4909   5222   5178
# INTEL_SOC_DTS_THERMAL      4564  4728  5224  5290   5583   5929   5763
# IOSF_MBI                   3650  3869   340  1749   4433   4727   4741
# SENSORS_NCT7904            6686  6815  7412  7512   7741   8244   8264
# SENSORS_GPIO_FAN           8123  8218  8894  9026   9452  10650  10841
# ACPI_DEBUG                  134    66   200   324     52     98     78
# MEDIA_SDR_SUPPORT          7618  7697  8340  1856   8870   9230   9378
# MEDIA_ANALOG_TV_SUPPORT    6964  1495  7755   459   8122   1851   8660
# MEDIA_CAMERA_SUPPORT       7522  7689  8302  1858   8798   1741   9403
# VIDEO_APTINA_PLL           5981  6134  6045  6115   7036   7450   7478
# MEDIA_CEC_SUPPORT          3757  3919  4362   465   4503   1852   4792
# RC_DECODERS                1943  2037  2503   792   2493   2697   2650
# PINCTRL_SX150X             8463  8632  9339  9358   9819    262  10530
# RC_DEVICES                 2670  2990   733  3409   3316   3574   3553
# ACPI_CONTAINER             1109  5820   126  1530    182    572    530
# VIDEO_ADV7842              2222  2513  2876  2922   2774    624   2962
# VIDEO_ADV7604              7486   813  8085  8170   8724   9146   9297
# VIDEO_ADV7180              8618  8728  9438  9519  10061  10493  10718
# MEDIA_CONTROLLER_DVB       2437  2757  3112  3167    440   1854   3226
# VIDEO_TC358743             8488  8543  9234  9391   9849  10494    701
# VIDEO_AD9389B              8370  8462  9168  9247    189   9826    484
# ACPI_PROCESSOR             1121  1057  2419  2382   1024   2702   2376
# DEVFREQ_THERMAL            5965  6115  1279  1422   7048    292   7525
# THERMAL_WRITABLE_TRIPS     6623  1034  7419   925   7735   8237   1081
# ACPI_HED                   1124  5310  5481  1525   5751   1577   1514
# PINCTRL_STM32              7274   709   782   273   8486   8830   9044
# VIDEO_ADV7604_CEC           674  7143  7592  7767   8183   8627   8733
# PINCTRL_MTK                 509  2753  3110  3164   3024   3304   3228
# VIDEO_ADV7511              6389  6526  7099  7186   7484   7882   7957
# CLK_SP810                  3551  3761  4092  4230   4277   4577   4468
# VIDEO_ADV7842_CEC          4778  4974  5605  1048   5890   6176   6231
# BLK_DEV_NVME                390    97  1494   144    721   1711   1631
# PINCTRL_SINGLE             8632  8569  9273  9537  10011  10541  10734
# PINCTRL_PXA27X             2464  2724  3077  3161   3022   3316    859
# TIMER_OF, TIMER_PROBE        72   481  1579  1341   7241   1387   4673
# ACPI_SLEEP                 2440  1041  1114   229   3032    610    524
# BIG_KEYS                   7909   694  8646  1629   9190   9302   9818
# PINCTRL_PXA25X             5913  6061  6630  6703   6992   7370   7454
# IOSF_MBI_DEBUG             1245  8925  2014  1748     94   2113   2035
# DEVFREQ_GOV_USERSPACE      7136  7559  1269  1423   1463   1487    305
# RC_MAP                     3177  3371  3754  3806    837   4300   4103
# CRAMFS                     1016  3641  1294  1262   4170   4464   4433
# HID_PICOLCD_CIR            5784  5829  6408  6560   6886   7255   7393
# CHARGER_TPS65217           4556  4747  5214  5267   1872   1665   5773
# QRTR                       5783  5928  6428  6547   6778   7075    584
# DMA_ACPI                   1592  2109  2465  2507   2070   1490   2377
# VIDEO_MT9P031              4861  4969  5601  5671   5885   6208   6217
# ACPI_FAN                   5729  5932  6433  1526    483    200   1515
# I2C_MUX_PINCTRL            8091  8167  8822  8958   9315   9759   9914
# VIDEO_OV13858              1617  2134  2132  2254   2103   2298   2176
# VIDEO_MT9T001              7101  7191  7813  7902   8290   8899   8828
# VIDEO_NOON010PC30          5219  5384  5912  5979   6211   6575    695
# VIDEO_OV5647               3270  3550  3879  3939   3985   4078   4256
# NVM                        7885  8069  8739   754   9171   9675    762
# VIDEO_S5K6AA               5829  5982  6535  6600   9633  10097  10267
#
#                            freq 4.13  freq 4.15  freq 4.20  freq 5.00  \
# UBSAN_ALIGNMENT             0.166850   0.250946   0.238409   0.256265
# PINCTRL                     0.314805   0.659761   0.861850   0.882618
# PINMUX                      0.314751   0.643385   0.854570   0.878508
# CEC_NOTIFIER                0.073421   0.213040   0.543531   0.550571
# VIDEO_V4L2_SUBDEV_API       0.138804   0.137787   0.140236   0.139234
# PM_OPP                      0.322314   0.633458   0.637362   0.637079
# RPMSG                       0.268112   0.615178   0.623015   0.669006
# CRYPTO_SEQIV                0.960643   0.969558   0.971646   0.971532
# PRIME_NUMBERS               0.262073   0.264377   0.257695   0.257468
# MEDIA_CONTROLLER            0.285139   0.290451   0.294138   0.287039
# GCC_PLUGIN_RANDSTRUCT       0.185789   0.186584   0.244838   0.250200
# GCC_PLUGIN_LATENT_ENTROPY   0.185054   0.186914   0.246584   0.245589
# GPIO_MB86S7X                0.240001   0.479625   0.485930   0.489124
# INTEL_SOC_DTS_IOSF_CORE     0.449418   0.345165   0.175316   0.172614
# PINCTRL_AMD                 0.155701   0.326453   0.430287   0.434292
# HID_WACOM                   0.352121   0.112956   0.110477   0.108962
# PINCTRL_MCP23S08            0.147339   0.304466   0.389246   0.404872
# PINCTRL_PXA                 0.141700   0.291264   0.385500   0.394046
# DEBUG_PINCTRL               0.138318   0.293650   0.370897   0.386929
# MFD_TPS65217                0.453534   0.226496   0.223722   0.231606
# HID_ASUS                    0.343856   0.344606   0.329601   0.328889
# MFD_TPS65218                0.453253   0.229644   0.226787   0.226744
# RC_CORE                     0.198840   0.406403   0.444932   0.453739
# GPIO_ACPI                   0.411951   0.424734   0.252969   0.498597
# SERIO_OLPC_APSP             0.226745   0.224693   0.225042   0.443464
# INTEL_SOC_DTS_THERMAL       0.361984   0.253028   0.123803   0.121792
# IOSF_MBI                    0.652039   0.556199   0.435864   0.423115
# SENSORS_NCT7904             0.398425   0.401858   0.377496   0.390988
# SENSORS_GPIO_FAN            0.388378   0.193084   0.197326   0.198025
# ACPI_DEBUG                  0.314006   0.323508   0.190728   0.375551
# MEDIA_SDR_SUPPORT           0.329174   0.324853   0.327898   0.326283
# MEDIA_ANALOG_TV_SUPPORT     0.327845   0.331683   0.334369   0.325431
# MEDIA_CAMERA_SUPPORT        0.328925   0.330160   0.329431   0.326634
# VIDEO_APTINA_PLL            0.034571   0.033437   0.031802   0.034984
# MEDIA_CEC_SUPPORT           0.328785   0.328357   0.331559   0.323627
# RC_DECODERS                 0.142899   0.291975   0.321470   0.325431
# PINCTRL_SX150X              0.214570   0.294640   0.366640   0.396602
# RC_DEVICES                  0.143277   0.289359   0.322491   0.326634
# ACPI_CONTAINER              0.279715   0.287455   0.168973   0.336307
# VIDEO_ADV7842               0.041000   0.041867   0.039508   0.043404
# VIDEO_ADV7604               0.040902   0.040953   0.042190   0.042151
# VIDEO_ADV7180               0.038590   0.039048   0.039976   0.041199
# MEDIA_CONTROLLER_DVB        0.080541   0.081220   0.083145   0.082749
# VIDEO_TC358743              0.040848   0.040140   0.038656   0.040948
# VIDEO_AD9389B               0.040935   0.040902   0.039508   0.040898
# ACPI_PROCESSOR              0.276615   0.281032   0.167866   0.330543
# DEVFREQ_THERMAL             0.111450   0.234468   0.223551   0.243986
# THERMAL_WRITABLE_TRIPS      0.684773   0.617336   0.504449   0.553528
# ACPI_HED                    0.262689   0.268109   0.161097   0.308591
# PINCTRL_STM32               0.074080   0.153985   0.218102   0.221231
# VIDEO_ADV7604_CEC           0.032659   0.032879   0.031930   0.031626
# PINCTRL_MTK                 0.076316   0.158809   0.218613   0.220830
# VIDEO_ADV7511               0.041237   0.040775   0.040785   0.041650
# CLK_SP810                   0.076630   0.075482   0.063732   0.091720
# VIDEO_ADV7842_CEC           0.033761   0.033031   0.033164   0.032829
# BLK_DEV_NVME                0.179458   0.288801   0.158925   0.152165
# PINCTRL_SINGLE              0.078088   0.163430   0.217293   0.217622
# PINCTRL_PXA27X              0.080206   0.163252   0.217591   0.221381
# TIMER_OF, TIMER_PROBE       0.504203   0.497398   0.503299   0.502807
# ACPI_SLEEP                  0.240995   0.247087   0.145898   0.289595
# BIG_KEYS                    0.228042   0.241704   0.221508   0.220279
# PINCTRL_PXA25X              0.080703   0.162668   0.214271   0.219878
# IOSF_MBI_DEBUG              0.380523   0.305532   0.245391   0.243234
# DEVFREQ_GOV_USERSPACE       0.290865   0.293346   0.297373   0.291249
# RC_MAP                      0.112552   0.228959   0.251394   0.259272
# CRAMFS                      0.181543   0.303044   0.284048   0.307889
# HID_PICOLCD_CIR             0.106782   0.220200   0.242794   0.247494
# CHARGER_TPS65217            0.244852   0.121995   0.121589   0.126303
# QRTR                        0.123323   0.122655   0.126400   0.121191
# DMA_ACPI                    0.301409   0.296494   0.176721   0.298667
# VIDEO_MT9P031               0.024567   0.023688   0.022010   0.025962
# ACPI_FAN                    0.287515   0.295884   0.173741   0.285886
# I2C_MUX_PINCTRL             0.113221   0.173738   0.220614   0.244988
# VIDEO_OV13858               0.025324   0.023790   0.022010   0.025812
# VIDEO_MT9T001               0.024643   0.023358   0.022138   0.024960
# VIDEO_NOON010PC30           0.024697   0.024120   0.022691   0.024258
# VIDEO_OV5647                0.024470   0.024831   0.022053   0.023757
# NVM                         0.304261   0.193820   0.312998   0.313452
# VIDEO_S5K6AA                0.024816   0.023637   0.022521   0.025110
#
#                            freq 5.04  freq 5.07  freq 5.08  outliers_score  \
# UBSAN_ALIGNMENT             0.748868   0.121931   0.126579        0.476033
# PINCTRL                     0.880721   0.882732   0.880901        0.451393
# PINMUX                      0.877742   0.878317   0.870091        0.444872
# CEC_NOTIFIER                0.562154   0.568580   0.691967        0.384188
# VIDEO_V4L2_SUBDEV_API       0.152358   0.146585   0.539935        0.340658
# PM_OPP                      0.720200   0.816658   0.824796        0.333667
# RPMSG                       0.661702   0.668138   0.667655        0.328003
# CRYPTO_SEQIV                0.955469   0.953867   0.611778        0.301721
# PRIME_NUMBERS               0.255426   0.260182   0.594946        0.287494
# MEDIA_CONTROLLER            0.314737   0.302793   0.602928        0.263325
# GCC_PLUGIN_RANDSTRUCT       0.499129   0.248574   0.256534        0.231751
# GCC_PLUGIN_LATENT_ENTROPY   0.492088   0.249864   0.248597        0.227132
# GPIO_MB86S7X                0.487639   0.492336   0.495826        0.212925
# INTEL_SOC_DTS_IOSF_CORE     0.171587   0.177836   0.176527        0.211066
# PINCTRL_AMD                 0.438117   0.434397   0.334854        0.209170
# HID_WACOM                   0.107014   0.104469   0.108699        0.208592
# PINCTRL_MCP23S08            0.405037   0.408056   0.418647        0.206613
# PINCTRL_PXA                 0.391573   0.397143   0.396479        0.200829
# DEBUG_PINCTRL               0.385151   0.385634   0.376545        0.195557
# MFD_TPS65217                0.228073   0.229327   0.228618        0.193337
# HID_ASUS                    0.329323   0.322982   0.108790        0.192360
# MFD_TPS65218                0.228615   0.231857   0.231401        0.192067
# RC_CORE                     0.447054   0.381914   0.379373        0.188625
# GPIO_ACPI                   0.495338   0.499926   0.501619        0.187764
# SERIO_OLPC_APSP             0.222502   0.222729   0.225152        0.187703
# INTEL_SOC_DTS_THERMAL       0.117074   0.121435   0.121106        0.187667
# IOSF_MBI                    0.427051   0.427253   0.426082        0.173810
# SENSORS_NCT7904             0.402058   0.396448   0.201888        0.165135
# SENSORS_GPIO_FAN            0.208767   0.205268   0.208366        0.159918
# ACPI_DEBUG                  0.373041   0.375614   0.379510        0.142409
# MEDIA_SDR_SUPPORT           0.331334   0.332011   0.492907        0.140841
# MEDIA_ANALOG_TV_SUPPORT     0.335977   0.332854   0.495005        0.140267
# MEDIA_CAMERA_SUPPORT        0.334081   0.329084   0.492679        0.139680
# VIDEO_APTINA_PLL            0.045963   0.048316   0.200338        0.138993
# MEDIA_CEC_SUPPORT           0.332766   0.334491   0.490809        0.137895
# RC_DECODERS                 0.329593   0.277593   0.275829        0.137785
# PINCTRL_SX150X              0.399776   0.398432   0.394335        0.137572
# RC_DEVICES                  0.319650   0.283099   0.274734        0.136615
# ACPI_CONTAINER              0.343367   0.349819   0.353738        0.133795
# VIDEO_ADV7842               0.056912   0.056154   0.201980        0.133291
# VIDEO_ADV7604               0.057415   0.055161   0.201524        0.132910
# VIDEO_ADV7180               0.055906   0.057443   0.199516        0.132134
# MEDIA_CONTROLLER_DVB        0.115526   0.110918   0.245176        0.130994
# VIDEO_TC358743              0.056293   0.056005   0.196597        0.129527
# VIDEO_AD9389B               0.055364   0.055211   0.195639        0.128717
# ACPI_PROCESSOR              0.326498   0.334441   0.337408        0.125620
# DEVFREQ_THERMAL             0.274229   0.281363   0.280254        0.124165
# THERMAL_WRITABLE_TRIPS      0.538554   0.537427   0.539707        0.116806
# ACPI_HED                    0.309823   0.314649   0.311180        0.115494
# PINCTRL_STM32               0.218014   0.221787   0.219039        0.115382
# VIDEO_ADV7604_CEC           0.047704   0.045042   0.171236        0.115082
# PINCTRL_MTK                 0.219755   0.222680   0.220271        0.114723
# VIDEO_ADV7511               0.049870   0.050350   0.177895        0.114672
# CLK_SP810                   0.087012   0.091225   0.213931        0.113969
# VIDEO_ADV7842_CEC           0.044918   0.047621   0.169457        0.113059
# BLK_DEV_NVME                0.151468   0.154174   0.149843        0.112396
# PINCTRL_SINGLE              0.218749   0.216628   0.220088        0.112183
# PINCTRL_PXA27X              0.215151   0.223622   0.224103        0.111981
# TIMER_OF, TIMER_PROBE       0.501915   0.509549   0.632760        0.111056
# ACPI_SLEEP                  0.289782   0.288407   0.296401        0.110983
# BIG_KEYS                    0.303826   0.302247   0.123797        0.110689
# PINCTRL_PXA25X              0.218401   0.221440   0.220955        0.110485
# IOSF_MBI_DEBUG              0.237087   0.247483   0.236738        0.109668
# DEVFREQ_GOV_USERSPACE       0.336674   0.335632   0.434065        0.108464
# RC_MAP                      0.249971   0.216578   0.220545        0.107344
# CRAMFS                      0.308469   0.314053   0.313506        0.105964
# HID_PICOLCD_CIR             0.242156   0.211766   0.203941        0.103951
# CHARGER_TPS65217            0.123070   0.124709   0.123888        0.103937
# QRTR                        0.121832   0.128379   0.245176        0.103897
# DMA_ACPI                    0.294967   0.301553   0.293345        0.103730
# VIDEO_MT9P031               0.033737   0.033385   0.147744        0.103302
# ACPI_FAN                    0.292374   0.297683   0.299001        0.102271
# I2C_MUX_PINCTRL             0.244516   0.254477   0.256489        0.102213
# VIDEO_OV13858               0.033079   0.033583   0.145874        0.101664
# VIDEO_MT9T001               0.034511   0.034178   0.145327        0.101168
# VIDEO_NOON010PC30           0.033195   0.033236   0.145008        0.101121
# VIDEO_OV5647                0.032576   0.034724   0.144916        0.101012
# NVM                         0.314621   0.315492   0.307120        0.100717
# VIDEO_S5K6AA                0.033660   0.034972   0.144506        0.100331
#
#                                         outliers
# UBSAN_ALIGNMENT             [0.7488683406198011]
# PINCTRL                     [0.3148052116419265]
# PINMUX                      [0.3147511937944297]
# CEC_NOTIFIER               [0.07342105831766815]
# VIDEO_V4L2_SUBDEV_API       [0.5399352278429047]
# PM_OPP                      [0.3223136924439835]
# RPMSG                       [0.2681121842656814]
# CRYPTO_SEQIV                [0.6117775851845094]
# PRIME_NUMBERS                [0.594945947178762]
# MEDIA_CONTROLLER            [0.6029284313278293]
# GCC_PLUGIN_RANDSTRUCT       [0.4991294927844624]
# GCC_PLUGIN_LATENT_ENTROPY   [0.4920880566410028]
# GPIO_MB86S7X               [0.24000129642833992]
# INTEL_SOC_DTS_IOSF_CORE     [0.4494176876039844]
# PINCTRL_AMD                [0.15570104362481363]
# HID_WACOM                  [0.35212074069272487]
# PINCTRL_MCP23S08           [0.14733908083230698]
# PINCTRL_PXA                [0.14169961755363972]
# DEBUG_PINCTRL              [0.13831810030033923]
# MFD_TPS65217                [0.4535338475832415]
# HID_ASUS                   [0.10878985540300141]
# MFD_TPS65218                [0.4532529547762581]
# RC_CORE                    [0.19883969663576845]
# GPIO_ACPI                  [0.25296947507343864]
# SERIO_OLPC_APSP            [0.44346431435445066]
# INTEL_SOC_DTS_THERMAL      [0.36198439964564294]
# IOSF_MBI                    [0.6520386335645297]
# SENSORS_NCT7904             [0.2018884276786936]
# SENSORS_GPIO_FAN           [0.38837751993258574]
# ACPI_DEBUG                 [0.19072757460939163]
# MEDIA_SDR_SUPPORT           [0.4929069926561146]
# MEDIA_ANALOG_TV_SUPPORT     [0.4950052456324408]
# MEDIA_CAMERA_SUPPORT       [0.49267892168042693]
# VIDEO_APTINA_PLL            [0.2003375450440177]
# MEDIA_CEC_SUPPORT          [0.49080873967978833]
# RC_DECODERS                [0.14289881376806898]
# PINCTRL_SX150X             [0.21456969382684038]
# RC_DEVICES                 [0.14327693870054667]
# ACPI_CONTAINER              [0.1689727106305079]
# VIDEO_ADV7842              [0.20197965606896867]
# VIDEO_ADV7604               [0.2015235141175934]
# VIDEO_ADV7180              [0.19951648953154222]
# MEDIA_CONTROLLER_DVB       [0.24517629886420655]
# VIDEO_TC358743              [0.1965971810427405]
# VIDEO_AD9389B              [0.19563928294485244]
# ACPI_PROCESSOR             [0.16786580952786412]
# DEVFREQ_THERMAL            [0.11144962295542447]
# THERMAL_WRITABLE_TRIPS      [0.6847734491475984]
# ACPI_HED                     [0.161096683554004]
# PINCTRL_STM32              [0.07408007605712928]
# VIDEO_ADV7604_CEC           [0.1712356885462756]
# PINCTRL_MTK                [0.07631641494349733]
# VIDEO_ADV7511               [0.1778953610363545]
# CLK_SP810                   [0.2139305751950007]
# VIDEO_ADV7842_CEC          [0.16945673493591207]
# BLK_DEV_NVME                [0.2888008733846193]
# PINCTRL_SINGLE              [0.0780882003413928]
# PINCTRL_PXA27X             [0.08020569996326786]
# TIMER_OF, TIMER_PROBE       [0.6327601149477717]
# ACPI_SLEEP                  [0.1458980799523181]
# BIG_KEYS                   [0.12379692560324773]
# PINCTRL_PXA25X             [0.08070266416023854]
# IOSF_MBI_DEBUG              [0.3805233249065491]
# DEVFREQ_GOV_USERSPACE      [0.43406468092870504]
# RC_MAP                     [0.11255158704435946]
# CRAMFS                     [0.18154318186728896]
# HID_PICOLCD_CIR            [0.10678248093169983]
# CHARGER_TPS65217            [0.2448520991335537]
# QRTR                       [0.24517629886420655]
# DMA_ACPI                   [0.17672101834901444]
# VIDEO_MT9P031               [0.1477443780504493]
# ACPI_FAN                    [0.1737408999957427]
# I2C_MUX_PINCTRL            [0.11322140835331994]
# VIDEO_OV13858               [0.1458741960498107]
# VIDEO_MT9T001              [0.14532682570816038]
# VIDEO_NOON010PC30          [0.14500752634219768]
# VIDEO_OV5647               [0.14491629795192265]
# NVM                         [0.1938202960367634]
# VIDEO_S5K6AA                [0.1445057701956849]

# %%
ovr._ranks_and_yes_frequencies["vmlinux"].loc["PINMUX"]
# Out:
# 4.13                              5686
# 4.15                               704
# 4.20                              6392
# 5.00                              6458
# 5.04                              6732
# 5.07                              7102
# 5.08                              7160
# freq 4.13                     0.314751
# freq 4.15                     0.643385
# freq 4.20                      0.85457
# freq 5.00                     0.878508
# freq 5.04                     0.877742
# freq 5.07                     0.878317
# freq 5.08                     0.870091
# outliers_score                0.444872
# outliers          [0.3147511937944297]
# Name: PINMUX, dtype: object

# %%
ovr._missing_options
# Out:
# {413: ['CLK_RCAR_GEN2_CPG',
#   'LCS',
#   'SND_SOC_TEGRA20_I2S',
#   'ATMEL_TCLIB',
#   'ARCH_BINFMT_ELF_STATE',
#   'UIO_FSL_ELBC_GPCM_NETX5152',
#   'PINCTRL_KIRKWOOD',
#   'PCI_GOMMCONFIG',
#   'RADIO_AZTECH',
#   'PARPORT_MFC3',
#   'CLK_R8A7791',
#   'ARM_PMU_ACPI',
#   'DRM_MSM',
#   'HAVE_EXIT_THREAD',
#   'FB_OLPC_DCON_1_5',
#   'USB_FUNCTIONFS_GENERIC',
#   'QE_USB',
#   'AU1000_FIR',
#   'SERIAL_8250_EM',
#   'USB_UHCI_BIG_ENDIAN_MMIO',
#   'XILINX_HWICAP',
#   'RENESAS_H8S_INTC',
#   'USB_BCM63XX_UDC',
#   'KERNEL_LZ4',
#   'SCLP_ASYNC',
#   'DASD',
#   'HAVE_KERNEL_GZIP',
#   'HAVE_DMA_API_DEBUG',
#   'MK6',
#   'MTD_NAND_CM_X270',
#   'ARM_PMU',
#   'SCSI_IBMVFC_TRACE',
#   'CRYPTO_DEV_UX500_HASH',
#   'RTC_DRV_MXC',
#   'RTC_DRV_AB8500',
#   'SERIAL_MPSC',
#   'CLK_R8A7796',
#   'PINCTRL_IMX6SX',
#   'VIRT_TO_BUS',
#   'EDAC_CELL',
#   'SERIAL_8250_OMAP',
#   'VIDEO_IMX_MEDIA',
#   'CPU_FREQ_PMAC64',
#   'BLK_DEV_IDE_AU1XXX_PIO_DBDMA',
#   'PCIE_RCAR',
#   'SERIAL_BFIN_CONSOLE',
#   'SENSORS_AMS_I2C',
#   'DRM_MSM_DSI_28NM_8960_PHY',
#   'BLK_DEV_IDEDMA_ICS',
#   'PATA_IXP4XX_CF',
#   'BFIN_MAC_USE_L1',
#   'SPEAR13XX_PCIE_GADGET',
#   'RTC_DRV_OPAL',
#   'SPI_S3C24XX_FIQ',
#   'OMAP_REMOTEPROC',
#   'SND_DM365_VOICE_CODEC',
#   'FB_MXS',
#   'INTEL_IOMMU_BROKEN_GFX_WA',
#   'TI_CPPI41',
#   'PINCTRL_U300',
#   'TXX9_DMAC',
#   'CLK_RENESAS_CPG_MSTP',
#   'MFD_PM8XXX',
#   'SERIAL_M32R_SIO',
#   'PINCTRL_TEGRA114',
#   'OMAP_GPMC',
#   'SQUASHFS_FILE_DIRECT',
#   'JZ4740_WDT',
#   'X86_CMOV',
#   'SSB_PCICORE_HOSTMODE',
#   'USB_MUSB_OMAP2PLUS',
#   'SND_OMAP_SOC_OMAP_ABE_TWL6040',
#   'SERIAL_8250_PXA',
#   'NET_VENDOR_MEDIATEK',
#   'INITRAMFS_COMPRESSION_LZMA',
#   'HISAX_SPORTSTER',
#   'INGENIC_IRQ',
#   'EDAC_AMD8111',
#   'SCSI_MESH',
#   'USB_OHCI_HCD_LPC32XX',
#   'RTC_DRV_EFI',
#   'SND_S3C24XX_I2S',
#   'HAVE_COPY_THREAD_TLS',
#   'MMC_DW_ZX',
#   'SERIAL_SUNZILOG',
#   'PINCTRL_ARMADA_38X',
#   'ARCH_INLINE_SPIN_LOCK_IRQSAVE',
#   'PCMCIA_XXS1500',
#   'PCI_AARDVARK',
#   'MFD_JZ4740_ADC',
#   'ATARI_FLOPPY',
#   'PPC_BESTCOMM',
#   'CRYPTO_CRC32C_VPMSUM',
#   'PINCTRL_ARTPEC6',
#   'GPIO_EP93XX',
#   'USB_UHCI_SUPPORT_NON_PCI_HC',
#   'DEBUG_PREEMPT',
#   'SND_BF6XX_SOC_SPORT',
#   'NET_VENDOR_XSCALE',
#   'PCIE_ALTERA_MSI',
#   'EDAC_MPC85XX',
#   'SA1100_WATCHDOG',
#   'MTD_PISMO',
#   'CONTEXT_TRACKING_FORCE',
#   'CLKSRC_NOMADIK_MTU_SCHED_CLOCK',
#   'PINCTRL_ST',
#   'CLKSRC_IMX_GPT',
#   'SCSI_ACORNSCSI_TAGGED_QUEUE',
#   'PWM_MESON',
#   'SND_S3C2412_SOC_I2S',
#   'ARCH_USE_QUEUED_SPINLOCKS',
#   'PSS_HAVE_BOOT',
#   'ARCH_INLINE_WRITE_LOCK_BH',
#   'OMAP_OCP2SCP',
#   'SERIAL_NETX',
#   'MFD_TMIO',
#   'SPAPR_TCE_IOMMU',
#   'PARPORT_ATARI',
#   'ARM_S3C24XX_CPUFREQ',
#   'MIPS_EJTAG_FDC_EARLYCON',
#   'INPUT_COBALT_BTNS',
#   'USB_G_MULTI_RNDIS',
#   'CPU_NO_EFFICIENT_FFS',
#   'RTL8192E',
#   'ARCH_THREAD_STACK_ALLOCATOR',
#   'SND_PXA2XX_LIB_AC97',
#   'SCSI_MAC53C94',
#   'ARM_CCI400_PMU',
#   'USB_OHCI_HCD_PXA27X',
#   'MTK_IOMMU_V1',
#   'SGI_IOC3_ETH',
#   'X86_USE_3DNOW',
#   'HW_RANDOM_HISI',
#   'RTC_DRV_TX4939',
#   'DRM_OMAP_PANEL_LGPHILIPS_LB035Q02',
#   'SERIAL_SUNSU',
#   'RCU_BOOST',
#   'GPM1040A0_320X240',
#   'M32R_PCC',
#   'COMMON_CLK_PXA',
#   'I2C_STUB',
#   'ARM_TI_CPUFREQ',
#   'PINCTRL_VT8500',
#   'SMSC911X_ARCH_HOOKS',
#   'ZCRYPT',
#   'USB_G_DBGP_PRINTK',
#   'ARCH_HAS_ASYNC_TX_FIND_CHANNEL',
#   'MVEBU_PIC',
#   'I2C_NOMADIK',
#   'RTC_DRV_BFIN',
#   'SPI_S3C24XX',
#   'I2C_CPM',
#   'BACKLIGHT_LOCOMO',
#   'PINCTRL_SUN50I_H5',
#   'DRM_HISI_KIRIN',
#   'LEDS_PM8058',
#   'MPSC',
#   'GENERIC_SCHED_CLOCK',
#   'KEYBOARD_PXA930_ROTARY',
#   'AT91_CF',
#   'SCC_DELAY',
#   'LANTIQ_ETOP',
#   'FB_FM2',
#   'ARMADA_370_XP_IRQ',
#   'MODULE_SIG_SHA224',
#   'HAS_DMA',
#   'PCMCIA_SYM53C500',
#   'PINCTRL_ARMADA_37XX',
#   'DRM_EXYNOS7_DECON',
#   'ARCH_TEGRA_210_SOC',
#   'TI_DAVINCI_CPDMA',
#   'RESET_A10SR',
#   'XILINX_AXI_EMAC',
#   'A2065',
#   'AX88796',
#   'MACE',
#   'SOUND_SB',
#   'SERIAL_MSM_CONSOLE',
#   'INLINE_READ_UNLOCK_BH',
#   'BATTERY_IPAQ_MICRO',
#   'ARCH_INLINE_READ_LOCK_BH',
#   'DRM_EXYNOS_VIDI',
#   'BFIN_WDT',
#   'ARCH_DISCONTIGMEM_ENABLE',
#   'INTEL_IOP_ADMA',
#   'TI_EMIF',
#   'FB_OMAP2_PANEL_TPO_TD028TTEC1',
#   'PATA_BK3710',
#   'DASD_PROFILE',
#   'FB_SH7760',
#   'PINCTRL_SUN8I_H3',
#   'HVC_OLD_HVSI',
#   'XEN_ACPI_HOTPLUG_CPU',
#   'ARM_SMMU',
#   'MOUSE_NAVPOINT_PXA27x',
#   'ARCH_WANT_GENERAL_HUGETLB',
#   'EDAC_PPC4XX',
#   'HAVE_PERF_REGS',
#   'I2C_HYDRA',
#   'USB_OHCI_HCD_S3C2410',
#   'QCOM_L2_PMU',
#   'USB_OHCI_BIG_ENDIAN_MMIO',
#   'RTC_DRV_AU1XXX',
#   'SCSI_POWERTECSCSI',
#   'MTD_NAND_SOCRATES',
#   'FB_OMAP2_DSS',
#   'EDAC_ALTERA_USB',
#   'FB_CT65550',
#   'AHCI_DA850',
#   'USB_CNS3XXX_EHCI',
#   'BACKLIGHT_IPAQ_MICRO',
#   'HAVE_EFFICIENT_UNALIGNED_ACCESS',
#   'SUNVNET',
#   'SUN4I_EMAC',
#   'MODULE_SIG_SHA512',
#   'INLINE_READ_LOCK_BH',
#   'VLYNQ_DEBUG',
#   'AT_XDMAC',
#   'PWM_SPEAR',
#   'RADIO_RTRACK2',
#   'VIDEO_BLACKFIN_PPI',
#   'PPC_BESTCOMM_FEC',
#   'SERIAL_VR41XX_CONSOLE',
#   'PCI_GOOLPC',
#   'ATMEL_TCB_CLKSRC',
#   'KASAN_INLINE',
#   'SND_PXA2XX_SOC_E740',
#   'HSEM_U8500',
#   'SCSI_CUMANA_2',
#   'SPARC_US2E_CPUFREQ',
#   'SERIAL_ETRAXFS',
#   'REGMAP_W1',
#   'PARTITION_PERCPU',
#   'PSERIES_CPUIDLE',
#   'SND_SOC_TTC_DKB',
#   'PATA_PXA',
#   'ARCH_USES_GETTIMEOFFSET',
#   'ARCH_INLINE_READ_TRYLOCK',
#   'QCOM_SMD_RPM',
#   'CXL',
#   'FB_APOLLO',
#   'PINCTRL_SPEAR',
#   '53C700_LE_ON_BE',
#   'SERIO_Q40KBD',
#   'INPUT_PMIC8XXX_PWRKEY',
#   'SND_SOC_SAMSUNG_S3C24XX_UDA134X',
#   'INITRAMFS_COMPRESSION_LZO',
#   'OMAP2_DSS',
#   'ARM_ETHER1',
#   'ROCKCHIP_IOMMU',
#   'NET_BFIN',
#   'MONWRITER',
#   'SND_SOC_ZYLONITE',
#   'SND_DA830_SOC_EVM',
#   'MODULES_TREE_LOOKUP',
#   'FB_BFIN_7393',
#   'USB_EHCI_HCD_PPC_OF',
#   'IUCV',
#   'FB_S3C2410',
#   'OCTEON_WDT',
#   'SCSI_LASI700',
#   'SERIO_RPCKBD',
#   'PINCTRL_PFC_R8A7791',
#   'SND_AOA_TOONIE',
#   'SOC_REALVIEW',
#   'NTSC_640x480',
#   'IBM_EMAC_ZMII',
#   'CLKSRC_LPC32XX',
#   'KERNEL_XZ',
#   'INLINE_WRITE_LOCK_IRQ',
#   'HW_RANDOM_BCM63XX',
#   'MTD_AFS_PARTS',
#   'USB_G_DBGP_SERIAL',
#   'SOUND_BCM_CS4297A',
#   'VEXPRESS_CONFIG',
#   'TI_SCI_PM_DOMAINS',
#   'IBMVETH',
#   'PINCTRL_COH901',
#   'IXP4XX_WATCHDOG',
#   'VIDEO_OMAP2_VOUT_VRFB',
#   'MCF8390',
#   'UCC_GETH',
#   'DRM_ETNAVIV',
#   'CMT_SPEECH',
#   'DRM_OMAP_ENCODER_OPA362',
#   'X86',
#   'MFD_DAVINCI_VOICECODEC',
#   'HAVE_DYNAMIC_FTRACE_WITH_REGS',
#   'SCSI_SNI_53C710',
#   'BLK_DEV_SWIM',
#   'LOGO_SUPERH_MONO',
#   'NET_NETX',
#   'SPI_COLDFIRE_QSPI',
#   'SERIAL_PXA',
#   'MTD_NAND_JZ4740',
#   'EDAC_I82443BXGX',
#   'MTD_NAND_BRCMNAND',
#   'SOUND_UART6850',
#   'SUNBMAC',
#   'NE2000',
#   'PSTORE_LZO_COMPRESS',
#   'ARM_GIC',
#   'SND_PXA2XX_SOC_IMOTE2',
#   'MMC_QCOM_DML',
#   'OF_NUMA',
#   'LEGACY_VSYSCALL_NONE',
#   'ARM_S3C2416_CPUFREQ',
#   'PATA_ISAPNP',
#   'ARM_GIC_V3',
#   'MVEBU_ICU',
#   'SERIAL_PIC32_CONSOLE',
#   'B43_BUSES_BCMA',
#   'SND_MIPS',
#   'SND_SOC_IMX_PCM_FIQ',
#   'MTK_SMI',
#   'HVC_OPAL',
#   'KEYBOARD_AMIGA',
#   'NTSC_YCBCR',
#   'EDAC_PASEMI',
#   'SND_DM6467_SOC_EVM',
#   'SND_SOC_IMX_SSI',
#   'PTP_1588_CLOCK_IXP46X',
#   'SND_MMP_SOC_BROWNSTONE',
#   'DRM_EXYNOS',
#   'SND_SOC_DB1200',
#   'IOP_WATCHDOG',
#   'VIDEO_IMX',
#   'PINCTRL_BF60x',
#   'FB_WM8505',
#   'BCMA_DRIVER_PCI_HOSTMODE',
#   'USB_S3C_HSUDC',
#   'NOKIA_MODEM',
#   'SND_SOC_MEDIATEK',
#   'FB_OMAP2_DSS_SDI',
#   'POWER_RESET_XGENE',
#   'SOUND_MSNDPIN',
#   'ARM_TEGRA124_CPUFREQ',
#   'BACKLIGHT_EP93XX',
#   'SPI_PL022',
#   'SERIAL_BFIN_UART3',
#   'REGULATOR_TI_ABB',
#   'ARCH_INLINE_SPIN_UNLOCK',
#   'CLOCKSOURCE_WATCHDOG',
#   'DEBUG_NOMMU_REGIONS',
#   'OMAP2_DSS_DSI',
#   'USB_S3C2410',
#   'SND_SOC_INTEL_BYT_RT5640_MACH',
#   'ARCH_INLINE_SPIN_UNLOCK_IRQRESTORE',
#   'SERIO_SA1111',
#   'BACKLIGHT_ATMEL_LCDC',
#   'HOTPLUG_PCI_RPA_DLPAR',
#   'HAVE_64BIT_ALIGNED_ACCESS',
#   'SND_SH7760_AC97',
#   'I2C_CADENCE',
#   'SC6600_JOY',
#   'SERIAL_SGI_IOC4',
#   'USB_G_NCM',
#   'TOUCHSCREEN_WM97XX_MAINSTONE',
#   'SPI_ATH79',
#   'SND_SOC_PHYCORE_AC97',
#   'DMA_NOOP_OPS',
#   'SNI_82596',
#   'AHCI_OCTEON',
#   'MMC_AU1X',
#   'MTD_NAND_OMAP_BCH',
#   'ARCH_INLINE_SPIN_LOCK_BH',
#   'JOYSTICK_AMIGA',
#   'SND_SOC_TXX9ACLC_GENERIC',
#   'WINDFARM_PM91',
#   'QCOM_ADSP_PIL',
#   'BERLIN2_ADC',
#   'KEYBOARD_HIL_OLD',
#   'ORION_IRQCHIP',
#   'QCOM_SMEM',
#   'LOGO_MAC_CLUT224',
#   'ARM_SCPI_CPUFREQ',
#   'STACKTRACE_SUPPORT',
#   'MTD_NAND_FSL_UPM',
#   'SND_ATMEL_AC97C',
#   '3C515',
#   'FSL_DPAA2_ETH',
#   'SND_AD1816A',
#   'AGP_HP_ZX1',
#   'RTC_DRV_PUV3',
#   'MODULE_SIG_SHA384',
#   'SND_SOC_AU1XI2SC',
#   'PINCTRL_SUN5I',
#   'GENERIC_IDLE_POLL_SETUP',
#   'IBM_EMAC_RGMII',
#   'MTD_NAND_PASEMI',
#   'CLK_R8A7794',
#   'USB_GADGET_TARGET',
#   'I2C_XGENE_SLIMPRO',
#   'TEGRA_MC',
#   'OSF4_COMPAT',
#   'I2C_ACORN',
#   'SERIAL_8250_MT6577',
#   'FB_ARMCLCD',
#   'RC32434_WDT',
#   'QCOM_RPMCC',
#   'PCIE_QCOM',
#   'TEST_ASYNC_DRIVER_PROBE',
#   'PNPBIOS_PROC_FS',
#   'MCP_SA11X0',
#   'SND_PXA2XX_SOC_TOSA',
#   'ARCH_SUPPORTS_UPROBES',
#   'SND_PXA2XX_SOC_AC97',
#   'GREYBUS_CAMERA',
#   'CLKSRC_EFM32',
#   'SND_PPC',
#   'PMAC_RACKMETER',
#   'VEXPRESS_SYSCFG',
#   'DCACHE_WORD_ACCESS',
#   'USB_OHCI_SH',
#   'PINCTRL_TZ1090',
#   'LOONGSON1_WDT',
#   'ARMADA_CP110_SYSCON',
#   'DRM_EXYNOS_FIMC',
#   'GENERIC_CALIBRATE_DELAY',
#   'RTC_DRV_LOONGSON1',
#   'MTD_VMU',
#   'PREEMPT_RCU',
#   'PWM_TIPWMSS',
#   'SND_SOC_MPC5200_AC97',
#   'PWM_OMAP_DMTIMER',
#   'HAVE_FB_ATMEL',
#   'WIZNET_BUS_DIRECT',
#   'ARM_KS8695_ETHER',
#   'SCSI_ZALON',
#   'USB_PXA25X_SMALL',
#   'USB_EHCI_ATH79',
#   'CLOCKSOURCE_VALIDATE_LAST_CYCLE',
#   'DASD_FBA',
#   'MSNDPIN_HAVE_BOOT',
#   'PINCTRL_SH_PFC',
#   'SND_SOC_UX500_MACH_MOP500',
#   'SERIAL_TXX9_STDSERIAL',
#   'PINCTRL_IMX51',
#   'SENSORS_AB8500',
#   'BCM47XX_NVRAM',
#   'SERIAL_BFIN_SPORT2_UART',
#   'QCOM_SCM_64',
#   'ADB_PMU_LED_DISK',
#   'MVEBU_DEVBUS',
#   'PCIE_MEDIATEK',
#   'ODD_RT_SIGACTION',
#   'ST_SLIM_REMOTEPROC',
#   'DA8XX_MSTPRI',
#   'SND_SOC_SH4_SSI',
#   'DRM_MSM_DSI_28NM_PHY',
#   'REGULATOR_QCOM_RPM',
#   'PHY_EXYNOS5250_SATA',
#   'QCOM_CLK_RPM',
#   'DRM_ARMADA',
#   'SENSORS_JZ4740',
#   'WATCHDOG_CP1XXX',
#   'MPENTIUMIII',
#   'SND_BF5XX_SOC_SPORT',
#   'AB8500_BM',
#   'MAC_SCSI',
#   'MMP_PANEL_TPOHVGA',
#   'EFI_PCDP',
#   'SND_PXA910_SOC',
#   'BATTERY_TOSA',
#   'MMP_DISP_SPI',
#   'CRC32_SARWATE',
#   'PINCTRL_SUN8I_A33',
#   'ISDN_DRV_AVMB1_B1ISA',
#   'ANSLCD',
#   'CLK_SH73A0',
#   'SPI_LOOPBACK_TEST',
#   'EDAC_HIGHBANK_MC',
#   'PINCTRL_PFC_SH73A0',
#   'FSL_BMAN_TEST',
#   'PAL',
#   'PWM_TEGRA',
#   'ARM_ETHER3',
#   'USB_EHCI_MXC',
#   'SCSI_IBMVSCSIS',
#   'HAVE_KPROBES',
#   'SND_AOA_FABRIC_LAYOUT',
#   'DMASOUND_ATARI',
#   'ARM_S3C_CPUFREQ',
#   'SND_AICA',
#   'ARCH_WANT_BATCHED_UNMAP_TLB_FLUSH',
#   'MMC_SDHCI_ST',
#   'PHY_MIPHY28LP',
#   'DRM_IMX_PARALLEL_DISPLAY',
#   'RADIO_TERRATEC',
#   'STE_DMA40',
#   'HISILICON_IRQ_MBIGEN',
#   'LOGO_SUN_CLUT224',
#   'PCIE_XILINX_NWL',
#   'MFD_ASIC3',
#   'PINCTRL_AT91',
#   'COMMON_CLK_MESON8B',
#   'GENERIC_SMP_IDLE_THREAD',
#   'SERIAL_MPSC_CONSOLE',
#   'WINDFARM_PM72',
#   'CRYPTO_DEV_FSL_CAAM_AHASH_API',
#   'WIZNET_BUS_INDIRECT',
#   'FB_PXA_OVERLAY',
#   'ARCH_DISCONTIGMEM_DEFAULT',
#   'DRM_OMAP_CONNECTOR_DVI',
#   'FB_AMIGA_ECS',
#   'TRIX_HAVE_BOOT',
#   'CLK_RENESAS_CPG_MSSR',
#   'SERIAL_SB1250_DUART_CONSOLE',
#   'KEYBOARD_SNVS_PWRKEY',
#   'SRAM_EXEC',
#   'MODULE_REL_CRCS',
#   'CLKSRC_EXYNOS_MCT',
#   'INDYDOG',
#   'SND_SOC_BFIN_EVAL_ADAU1373',
#   'FB_OMAP4_DSS_HDMI',
#   'SPI_ATMEL_QUADSPI',
#   'ADB_MACII',
#   'GENERIC_TIME_VSYSCALL_OLD',
#   'PHY_MT65XX_USB3',
#   'HYSDN',
#   'I2C_IOP3XX',
#   'IMX_GPCV2',
#   'ARCH_CLOCKSOURCE_DATA',
#   'QE_TDM',
#   'CPU_FREQ_CBE',
#   'CLPS711X_IRQCHIP',
#   'LEGACY_VSYSCALL_NATIVE',
#   'ARM_ZYNQ_CPUIDLE',
#   'BFIN_JTAG_COMM',
#   'PCIEASPM_PERFORMANCE',
#   'SERIAL_IP22_ZILOG',
#   'PCI_LAYERSCAPE',
#   'HW_RANDOM_MXC_RNGA',
#   'ARCH_INLINE_READ_LOCK',
#   'OMAP_DSS_BASE',
#   'TN3270_FS',
#   'CMA_SIZE_SEL_MIN',
#   'PCI_TEGRA',
#   'ARM_KIRKWOOD_CPUIDLE',
#   'SCSI_IBMVFC',
#   'MMC_S3C',
#   'NVMEM_SUNXI_SID',
#   'AB8500_CORE',
#   'VFIO_PLATFORM',
#   'ARCH_WANT_HUGE_PMD_SHARE',
#   'DEBUG_IMR_SELFTEST',
#   'FS_ENET',
#   'MGEODEGX1',
#   'SA1100_FIR',
#   'MCORE2',
#   'DMA_SUN4I',
#   'CLK_R8A7743',
#   'CRYPTO_CRCT10DIF_VPMSUM',
#   'B43_BUSES_SSB',
#   'SCTP_DEFAULT_COOKIE_HMAC_NONE',
#   'BLK_DEV_IDE_PMAC_ATA100FIRST',
#   'MTD_CFI_FLAGADM',
#   'NO_GENERIC_PCI_IOPORT_MAP',
#   'USB_TI_CPPI_DMA',
#   'DA_TTY',
#   'SOUND_YM3812',
#   'PHY_QCOM_IPQ806X_SATA',
#   'MMC_WMT',
#   'HANDLE_DOMAIN_IRQ',
#   'QCOM_Q6V5_PIL',
#   'TOUCHSCREEN_LPC32XX',
#   'PWM_EP93XX',
#   'SND_BF5XX_SOC_I2S',
#   'SPEAKUP_SYNTH_DECPC',
#   'INPUT_IXP4XX_BEEPER',
#   'FSL_IFC',
#   'SERIAL_NETX_CONSOLE',
#   'MTD_NAND_MLC_LPC32XX',
#   'IPMI_POWERNV',
#   'AT91_ADC',
#   'SND_AOA_TAS',
#   'QCOM_CLK_SMD_RPM',
#   'AMBA_PL08X',
#   'INPUT_SGI_BTNS',
#   'ARM_GIC_V2M',
#   'SOUND_PRIME',
#   'PINCTRL_IMX35',
#   'MTD_NAND_SUNXI',
#   'LEDS_LOCOMO',
#   'PINCTRL_SAMSUNG',
#   'OMAP_SSI',
#   'SERIAL_ICOM',
#   'PINCTRL_SUN4I_A10',
#   'PINCTRL_BF54x',
#   'MIPS_PLATFORM_DEVICES',
#   'INLINE_WRITE_TRYLOCK',
#   'SND_SOC_SAMSUNG_RX1950_UDA1380',
#   'PERCPU_TEST',
#   'ARCH_TEGRA_2x_SOC',
#   'QCOM_WCNSS_PIL',
#   'USB_OHCI_HCD_AT91',
#   'SCSI_SUNESP',
#   'MTD_NAND_S3C2410_DEBUG',
#   'STA2X11_VIP',
#   'PHY_SUN4I_USB',
#   'PINCTRL_EXYNOS5440',
#   'SAMPLE_HW_BREAKPOINT',
#   'IBMVNIC',
#   'AGP_UNINORTH',
#   'ARM_BIG_LITTLE_CPUIDLE',
#   'POWER_RESET_AXXIA',
#   'MTD_NAND_QCOM',
#   'FTMAC100',
#   'ST_THERMAL_SYSCFG',
#   'ARMADA_XP_CLK',
#   'EDAC_ALTERA_SDMMC',
#   'USB_OHCI_HCD_SPEAR',
#   'MAC8390',
#   'RENESAS_INTC_IRQPIN',
#   'DA8XX_DDRCTL',
#   'SELECT_MEMORY_MODEL',
#   'SND_SOC_UX500_PLAT_DMA',
#   'FB_Q40',
#   'IO_DELAY_NONE',
#   'THREAD_INFO_IN_TASK',
#   'SERIAL_BFIN_SPORT1_UART_CTSRTS',
#   'BLK_DEV_IDE_AU1XXX',
#   'RTC_DRV_TWL92330',
#   'TI_KEYSTONE_NETCP',
#   'FB_BW2',
#   'ST_REMOTEPROC',
#   'SND_SOC_AU1XPSC_AC97',
#   'DRM_EXYNOS_HDMI',
#   'XGENE_SLIMPRO_MBOX',
#   'MVEBU_CLK_CPU',
#   'ARM_S3C2440_CPUFREQ',
#   'DRM_HDLCD',
#   'DRM_MALI_DISPLAY',
#   'FB_ATMEL',
#   'HMC_DRV',
#   'MMC_MESON_GX',
#   'FB_WMT_GE_ROPS',
#   'THERM_WINDTUNNEL',
#   'PWM_BERLIN',
#   'PCI_HOST_THUNDER_PEM',
#   'MMP_DISP',
#   'MX3_IPU',
#   'FB_S3C2410_DEBUG',
#   'ULTRA',
#   'PINCTRL_SPEAR3XX',
#   'ICST',
#   'USB_FUNCTIONFS',
#   'KS8695_WATCHDOG',
#   'S390_CCW_IOMMU',
#   'KEYSTONE_TIMER',
#   'GPIO_VF610',
#   'HAVE_OPROFILE',
#   'DEFAULT_SFQ',
#   'SPI_ADI_V3',
#   'USB_OHCI_HCD_OMAP1',
#   'GENERIC_IRQ_IPI',
#   'NET_VENDOR_XILINX',
#   'LEDS_FSG',
#   'LANTIQ_WDT',
#   'FB_NUC900',
#   'RASPBERRYPI_POWER',
#   'CLONE_BACKWARDS3',
#   'NET_VENDOR_NUVOTON',
#   'SND_SOC_AU1XAUDIO',
#   'HISAX_MIC',
#   'CPU_FREQ_DEFAULT_GOV_USERSPACE',
#   'RTC_DRV_RS5C313',
#   'DEBUG_SLAB_LEAK',
#   'MMC_TMIO',
#   'PCI_IMX6',
#   'SIR_BFIN_PIO',
#   'DRM_OMAP_PANEL_DSI_CM',
#   'UCC_FAST',
#   'USB_TI_CPPI41_DMA',
#   'INLINE_WRITE_LOCK_IRQSAVE',
#   'OR1K_PIC',
#   'RTL8192U',
#   'LTE_GDM724X',
#   'SOUND_VMIDI',
#   'ARM_S3C24XX_CPUFREQ_IODEBUG',
#   'MFD_T7L66XB',
#   'IIO_BFIN_TMR_TRIGGER',
#   'ARCH_TEGRA_3x_SOC',
#   'SND_AOA_SOUNDBUS_I2S',
#   'SERIAL_BFIN_SPORT0_UART',
#   'POWER_RESET_AT91_POWEROFF',
#   'VIRT_CPU_ACCOUNTING',
#   'ARM_KIRKWOOD_CPUFREQ',
#   'VIRT_CPU_ACCOUNTING_NATIVE',
#   'SOUND_DMAP',
#   'NWBUTTON',
#   'XILINX_INTC',
#   'DT_IDLE_STATES',
#   'MENELAUS',
#   'PINCTRL_SUN8I_A23',
#   'VMCP',
#   'MTD_LANTIQ',
#   'CAN_BFIN',
#   'PCI_LOCKLESS_CONFIG',
#   'PHY_RCAR_GEN2',
#   'SERIAL_MCF',
#   'SERIAL_PMACZILOG_CONSOLE',
#   'HAS_IOPORT_MAP',
#   'DRM_RCAR_VSP',
#   'LUSTRE_FS',
#   'QORIQ_CPUFREQ',
#   'CRYPTO_DEV_UX500_DEBUG',
#   'FB_MBX_DEBUG',
#   'CAN_RCAR',
#   'ELAN_CPUFREQ',
#   'REGULATOR_QCOM_SMD_RPM',
#   'CRYPTO_MD5_PPC',
#   'HW_RANDOM_OMAP',
#   'SGI_NEWPORT_CONSOLE',
#   'ZX2967_WATCHDOG',
#   'MTD_NAND_FSL_ELBC',
#   'KEYBOARD_SPEAR',
#   'HAVE_RCU_TABLE_FREE',
#   'INLINE_READ_UNLOCK_IRQRESTORE',
#   'DMASCC',
#   'UCC',
#   'TEST_USER_COPY',
#   'FB_DA8XX',
#   'PINCTRL_PISTACHIO',
#   'USB_EHCI_HCD_AT91',
#   'EEPROM_DIGSY_MTC_CFG',
#   'RTC_DRV_SIRFSOC',
#   'TEST_STATIC_KEYS',
#   'KORINA',
#   'SYSCTL_ARCH_UNALIGN_NO_WARN',
#   'PCMCIA_SA1100',
#   'CPU_FREQ_DEFAULT_GOV_ONDEMAND',
#   'TILE_SROM',
#   'SERIAL_MESON',
#   'CLK_R8A7778',
#   'SAMPLE_SECCOMP',
#   'WINDFARM_PM112',
#   'SH_CPU_FREQ',
#   'PIC32_EVIC',
#   'SND_SOC_POWERPC_DMA',
#   'HAVE_KERNEL_BZIP2',
#   'CRYPTO_DEV_MV_CESA',
#   'I2C_PMCMSP',
#   'ARCH_INLINE_WRITE_LOCK_IRQ',
#   'TEGRA_IOMMU_GART',
#   'GPIO_OCTEON',
#   'PATA_FALCON',
#   'SND_SOC_SAMSUNG_NEO1973_WM8753',
#   'QCOM_SMP2P',
#   'GPIO_MM_LANTIQ',
#   'SERIAL_BFIN',
#   'CRYPTO_ACOMP',
#   'SND_PXA2XX_SOC_E800',
#   'FB_OMAP2_PANEL_SHARP_LS037V7DW01',
#   'X86_INTEL_QUARK',
#   'PCMCIA_AHA152X',
#   'ARCH_WEAK_RELEASE_ACQUIRE',
#   'SND_CMI8330',
#   'USB_ZERO',
#   'STI_RESET_SYSCFG',
#   'I2C_PXA_SLAVE',
#   'THERMAL_DEFAULT_GOV_POWER_ALLOCATOR',
#   'HWSPINLOCK_SIRF',
#   'RTC_MC146818_LIB',
#   'ATARI_KBD_CORE',
#   'FB_OMAP2_ENCODER_TFP410',
#   'M586TSC',
#   'WDT_MTX1',
#   'MFD_TC6387XB',
#   'SERIAL_21285_CONSOLE',
#   'SCSI_ARXESCSI',
#   'MFD_DB8500_PRCMU',
#   'TEST_BPF',
#   'FB_VALKYRIE',
#   'MTD_ONENAND_SAMSUNG',
#   'CRYPTO_DEV_FSL_CAAM_JR',
#   'XPS_USB_HCD_XILINX',
#   'VERSATILE_FPGA_IRQ',
#   'ARM_SPEAR_CPUFREQ',
#   'SOUND_PAS',
#   'RADIO_MIROPCM20',
#   'SCSI_EATA_PIO',
#   'USB_PXA25X',
#   'MAC89x0',
#   'DISCONTIGMEM',
#   'HYDRA',
#   'HI6220_MBOX',
#   'CLK_R8A7792',
#   'TEGRA_HOST1X',
#   'BVME6000_SCSI',
#   'DRM_SHMOBILE',
#   'WATCHDOG_RTAS',
#   'AUTO_IRQ_AFFINITY',
#   'PMAC_MEDIABAY',
#   'CPU_PM',
#   'VMLOGRDR',
#   'MTD_NAND_OMAP2',
#   'RTC_LIB',
#   'M586MMX',
#   'STRICT_KERNEL_RWX',
#   'ARM_CCN',
#   'HAVE_KERNEL_LZ4',
#   'HW_RANDOM_XGENE',
#   'PWM_BRCMSTB',
#   'GENERIC_EARLY_IOREMAP',
#   'BCM47XX_SPROM',
#   'PCI_XGENE',
#   'CRYPTO_SHA1_OCTEON',
#   'S390_VMUR',
#   'AFIUCV',
#   'PCI_RCAR_GEN2',
#   'I2C_PASEMI',
#   'PWM_MXS',
#   'PCIE_SPEAR13XX',
#   'VMSPLIT_2G_OPT',
#   'SND_ATMEL_SOC_TSE850_PCM5142',
#   'BMAC',
#   'ARCH_INLINE_READ_LOCK_IRQSAVE',
#   'BINFMT_SHARED_FLAT',
#   'SND_BF5XX_I2S',
#   'SUNVDC',
#   'ARCH_WANT_NUMA_VARIABLE_LOCALITY',
#   'CRYPTO_DEV_NX_COMPRESS_POWERNV',
#   'GPIO_ALTERA_A10SR',
#   'SERIAL_SA1100',
#   'QCOM_WCNSS_CTRL',
#   'HW_RANDOM_BCM2835',
#   'GPIO_VR41XX',
#   'FB_OMAP2_ENCODER_TPD12S015',
#   'DRM_MESON',
#   'AHCI_ST',
#   'EFI_ARMSTUB',
#   'SND_SOC_MT2701_CS42448',
#   'SND_SOC_TEGRA20_AC97',
#   'INSTRUCTION_DECODER',
#   'MINIX_FS_NATIVE_ENDIAN',
#   'SND_SUN_DBRI',
#   'USB_G_NOKIA',
#   'SERIAL_BFIN_SPORT3_UART_CTSRTS',
#   'ARCH_DISCARD_MEMBLOCK',
#   'ARCH_SUPPORTS_DEFERRED_STRUCT_PAGE_INIT',
#   'SPI_AU1550',
#   'HISAX_ASUSCOM',
#   'PCI_DRA7XX_HOST',
#   'PWM_IMX',
#   'ROCKCHIP_TIMER',
#   'TWL4030_USB',
#   'TC35815',
#   'CRYPTO_SHA512_OCTEON',
#   'SERIAL_PIC32',
#   'MTD_MS02NV',
#   'BLK_DEV_MAC_IDE',
#   'ARCH_SUPPORTS_DEBUG_PAGEALLOC',
#   'SND_PXA2XX_AC97',
#   'BFIN_SIR2',
#   'FSL_ERRATUM_A008585',
#   'FB_G364',
#   'OLD_SIGSUSPEND',
#   'SND_SOC_NUC900EVB',
#   'PINCTRL_PFC_R8A7779',
#   'IRQ_PREFLOW_FASTEOI',
#   'DRM_ATMEL_HLCDC',
#   'I2C_MPC',
#   'ROCKCHIP_DW_MIPI_DSI',
#   'CLKSRC_ARM_GLOBAL_TIMER_SCHED_CLOCK',
#   'DRM_MESON_DW_HDMI',
#   'INITRAMFS_COMPRESSION_BZIP2',
#   'CLK_R8A7795',
#   'SND_SOC_TXX9ACLC_AC97',
#   'RT2X00_LIB_SOC',
#   'SAMPLE_LIVEPATCH',
#   'AX88796_93CX6',
#   'ORION_WATCHDOG',
#   'KEYBOARD_TEGRA',
#   'DEFAULT_CODEL',
#   'ARCH_HAS_TICK_BROADCAST',
#   'SGI_TIOCX',
#   'TN3270_TTY',
#   'CRYPTO_CRC32_S390',
#   'SND_SOC_MT8173_MAX98090',
#   'DRM_STM',
#   'SERIAL_BFIN_PIO',
#   'LS_SCFG_MSI',
#   'ARCH_OPTIONAL_KERNEL_RWX_DEFAULT',
#   'CCWGROUP',
#   'TWL6030_USB',
#   'PINCTRL_PFC_SH7264',
#   'ARCH_HAS_CACHE_LINE_SIZE',
#   'HWSPINLOCK_OMAP',
#   'POWERNV_OP_PANEL',
#   'HAVE_DEBUG_KMEMLEAK',
#   'OMAP2_VRFB',
#   'ARM_PSCI_CHECKER',
#   'SENSORS_AMS_PMU',
#   'SND_GSC',
#   'USB_UHCI_BIG_ENDIAN_DESC',
#   'MMIOTRACE_TEST',
#   'HW_RANDOM_PIC32',
#   'QETH_IPV6',
#   'PINCTRL_PFC_SH7734',
#   'MVME147_NET',
#   'IMA_DEFAULT_HASH_SHA512',
#   'FB_OMAP2_DSS_VENC',
#   'MMC_SDHCI_CNS3XXX',
#   'ISP1301_OMAP',
#   'QCOM_SCM_32',
#   'LCD_HP700',
#   'KMEMCHECK_DISABLED_BY_DEFAULT',
#   'DRM_EXYNOS_GSC',
#   'RTC_DRV_DS17285',
#   'FB_PXA168',
#   'POWERNV_CPUIDLE',
#   'VIDEO_BLACKFIN_CAPTURE',
#   'LOGO_SGI_CLUT224',
#   'HWSPINLOCK_SPRD',
#   'BLK_DEV_CY82C693',
#   'BFIN_UART3_CTSRTS',
#   'PINCTRL_DIGICOLOR',
#   'PINCTRL_AT91PIO4',
#   'HISAX_IX1MICROR2',
#   'PINCTRL_IMX7D',
#   'FB_HIT',
#   'PKEY',
#   'OMAP2_DSS_DEBUGFS',
#   'EP93XX_ETH',
#   'MTK_PMIC_WRAP',
#   'A2091_SCSI',
#   'QCOM_BAM_DMA',
#   'MMC_SDHCI_ESDHC_IMX',
#   'SERIAL_8250_FSL',
#   'PINCTRL_PFC_SH7724',
#   'HVC_RTAS',
#   'PHY_MVEBU_SATA',
#   'MODULE_COMPRESS_XZ',
#   'AGP_I460',
#   'PHY_S5PV210_USB2',
#   'SND_SOC_BFIN_EVAL_ADAV80X',
#   'EXYNOS_PMU_ARM_DRIVERS',
#   'GENERIC_ARCH_TOPOLOGY',
#   'RTC_DRV_STARFIRE',
#   'EDAC_OCTEON_PCI',
#   'STI_CONSOLE',
#   'SERIO_NVEC_PS2',
#   'GADGET_UAC1_LEGACY',
#   'SND_SOC_IMX_MC13783',
#   'FB_PXA',
#   'PIC32_DMT',
#   'MTD_LPDDR2_NVM',
#   'MTK_IOMMU',
#   'SERIAL_BFIN_SPORT_CONSOLE',
#   'SSB_POSSIBLE',
#   'NO_HZ_FULL',
#   'AVR32_AT32AP_CPUFREQ',
#   'NET_VENDOR_PASEMI',
#   'SERIAL_BFIN_SPORT0_UART_CTSRTS',
#   'HAVE_FUNCTION_GRAPH_TRACER',
#   'PWM_BFIN',
#   'PCIE_DW_EP',
#   'BFIN_SIR1',
#   'SATA_AHCI_SEATTLE',
#   'PINCTRL_NOMADIK',
#   'ACPI_SPCR_TABLE',
#   'MPENTIUMII',
#   'INITRAMFS_COMPRESSION_LZ4',
#   'WINDFARM_PM121',
#   'DRM_OMAP_PANEL_DPI',
#   'CRYPTO_AES_SPARC64',
#   'USB_OHCI_LITTLE_ENDIAN',
#   'SMC911X',
#   'POWER_RESET_AT91_RESET',
#   'FB_PXA_SMARTPANEL',
#   'USB_OHCI_HCD_PPC_OF_LE',
#   'SND_DAVINCI_SOC_GENERIC_EVM',
#   'MMC_DW_ROCKCHIP',
#   'ATH5K_AHB',
#   'ARCH_HAS_UBSAN_SANITIZE_ALL',
#   'CLK_VEXPRESS_OSC',
#   'SOC_INTEGRATOR_CM',
#   'GENERIC_IRQ_SHOW',
#   'DRM_EXYNOS_IOMMU',
#   'MTD_NAND_SHARPSL',
#   'STM32_EXTI',
#   'MVEBU_CLK_COMMON',
#   'FB_MX3',
#   'MK7',
#   'DRM_IMX',
#   'FSL_QMAN_TEST',
#   'SND_EP93XX_SOC_I2S',
#   'ARCH_INLINE_READ_UNLOCK_IRQRESTORE',
#   'CLKSRC_TI_32K',
#   'DRM_EXYNOS_MIXER',
#   'ARCH_SELECT_MEMORY_MODEL',
#   'SERIAL_SB1250_DUART',
#   'KEYBOARD_NVEC',
#   'NTSC',
#   'CLK_R8A73A4',
#   'GPIO_TZ1090_PDC',
#   'SND_POWERMAC_AUTO_DRC',
#   'TN3215_CONSOLE',
#   'CPU_FREQ_MAPLE',
#   ...],
#  415: ['LCS',
#   'ATMEL_TCLIB',
#   'ARCH_BINFMT_ELF_STATE',
#   'UIO_FSL_ELBC_GPCM_NETX5152',
#   'ARCH_ENABLE_SPLIT_PMD_PTLOCK',
#   'PINCTRL_KIRKWOOD',
#   'PCI_GOMMCONFIG',
#   'RADIO_AZTECH',
#   'PARPORT_MFC3',
#   'ARM_PMU_ACPI',
#   'PHY_MTK_TPHY',
#   'DRM_MSM',
#   'HAVE_EXIT_THREAD',
#   'FB_OLPC_DCON_1_5',
#   'USB_FUNCTIONFS_GENERIC',
#   'QE_USB',
#   'AU1000_FIR',
#   'SERIAL_8250_EM',
#   'USB_UHCI_BIG_ENDIAN_MMIO',
#   'XILINX_HWICAP',
#   'RENESAS_H8S_INTC',
#   'CLONE_BACKWARDS',
#   'USB_BCM63XX_UDC',
#   'KERNEL_LZ4',
#   'SCLP_ASYNC',
#   'DASD',
#   'HAVE_KERNEL_GZIP',
#   'HAVE_DMA_API_DEBUG',
#   'MK6',
#   'MTD_NAND_CM_X270',
#   'ARM_PMU',
#   'SCSI_IBMVFC_TRACE',
#   'CRYPTO_DEV_UX500_HASH',
#   'B43LEGACY_PCI_AUTOSELECT',
#   'RTC_DRV_MXC',
#   'RTC_DRV_AB8500',
#   'SERIAL_MPSC',
#   'PINCTRL_IMX6SX',
#   'VIRT_TO_BUS',
#   'EDAC_CELL',
#   'SERIAL_8250_OMAP',
#   'VIDEO_IMX_MEDIA',
#   'CPU_FREQ_PMAC64',
#   'BLK_DEV_IDE_AU1XXX_PIO_DBDMA',
#   'PCIE_RCAR',
#   'SERIAL_BFIN_CONSOLE',
#   'SENSORS_AMS_I2C',
#   'DRM_MSM_DSI_28NM_8960_PHY',
#   'BLK_DEV_IDEDMA_ICS',
#   'PATA_IXP4XX_CF',
#   'BFIN_MAC_USE_L1',
#   'SND_GUSCLASSIC',
#   'SPEAR13XX_PCIE_GADGET',
#   'RTC_DRV_OPAL',
#   'SPI_S3C24XX_FIQ',
#   'OMAP_REMOTEPROC',
#   'SND_DM365_VOICE_CODEC',
#   'FB_MXS',
#   'INTEL_IOMMU_BROKEN_GFX_WA',
#   'TI_CPPI41',
#   'PINCTRL_U300',
#   'TXX9_DMAC',
#   'MFD_PM8XXX',
#   'SERIAL_M32R_SIO',
#   'PINCTRL_TEGRA114',
#   'OMAP_GPMC',
#   'SQUASHFS_FILE_DIRECT',
#   'JZ4740_WDT',
#   'X86_CMOV',
#   'SSB_PCICORE_HOSTMODE',
#   'USB_MUSB_OMAP2PLUS',
#   'SND_OMAP_SOC_OMAP_ABE_TWL6040',
#   'SERIAL_8250_PXA',
#   'NET_VENDOR_MEDIATEK',
#   'INITRAMFS_COMPRESSION_LZMA',
#   'HISAX_SPORTSTER',
#   'HARDLOCKUP_CHECK_TIMESTAMP',
#   'EDAC_AMD8111',
#   'INGENIC_IRQ',
#   'EDAC_I82860',
#   'SCSI_MESH',
#   'ISAPNP',
#   'USB_OHCI_HCD_LPC32XX',
#   'RTC_DRV_EFI',
#   'SND_S3C24XX_I2S',
#   'HAVE_COPY_THREAD_TLS',
#   'SPARSEMEM_ALLOC_MEM_MAP_TOGETHER',
#   'MMC_DW_ZX',
#   'SERIAL_8250_HUB6',
#   'SERIAL_SUNZILOG',
#   'PINCTRL_ARMADA_38X',
#   'ARCH_INLINE_SPIN_LOCK_IRQSAVE',
#   'PCMCIA_XXS1500',
#   'OLPC',
#   'PCI_AARDVARK',
#   'HISI_PMU',
#   'MFD_JZ4740_ADC',
#   'ATARI_FLOPPY',
#   'PPC_BESTCOMM',
#   'CRYPTO_CRC32C_VPMSUM',
#   'PINCTRL_ARTPEC6',
#   'GPIO_EP93XX',
#   'USB_UHCI_SUPPORT_NON_PCI_HC',
#   'DEBUG_PREEMPT',
#   'SND_BF6XX_SOC_SPORT',
#   'B44_PCI',
#   'NET_VENDOR_XSCALE',
#   'PCIE_ALTERA_MSI',
#   'EDAC_MPC85XX',
#   'SA1100_WATCHDOG',
#   'MTD_PISMO',
#   'CONTEXT_TRACKING_FORCE',
#   'CLKSRC_NOMADIK_MTU_SCHED_CLOCK',
#   'PINCTRL_ST',
#   'CLKSRC_IMX_GPT',
#   'SCSI_ACORNSCSI_TAGGED_QUEUE',
#   'PWM_MESON',
#   'SND_S3C2412_SOC_I2S',
#   'ARCH_USE_QUEUED_SPINLOCKS',
#   'ARCH_INLINE_WRITE_LOCK_BH',
#   'OMAP_OCP2SCP',
#   'SERIAL_NETX',
#   'MFD_TMIO',
#   'SPAPR_TCE_IOMMU',
#   'R8822BE',
#   'PARPORT_ATARI',
#   'ARM_S3C24XX_CPUFREQ',
#   'MIPS_EJTAG_FDC_EARLYCON',
#   'INPUT_COBALT_BTNS',
#   'USB_G_MULTI_RNDIS',
#   'CPU_NO_EFFICIENT_FFS',
#   'RTL8192E',
#   'ARCH_THREAD_STACK_ALLOCATOR',
#   'SND_PXA2XX_LIB_AC97',
#   'SCSI_MAC53C94',
#   'ARM_CCI400_PMU',
#   'USB_OHCI_HCD_PXA27X',
#   'MTK_IOMMU_V1',
#   'X86_USE_3DNOW',
#   'SGI_IOC3_ETH',
#   'HW_RANDOM_HISI',
#   'RTC_DRV_TX4939',
#   'DRM_OMAP_PANEL_LGPHILIPS_LB035Q02',
#   'INPUT_WISTRON_BTNS',
#   'SERIAL_SUNSU',
#   'RCU_BOOST',
#   'GPM1040A0_320X240',
#   'M32R_PCC',
#   'COMMON_CLK_PXA',
#   'I2C_STUB',
#   'ARM_TI_CPUFREQ',
#   'SSB_DRIVER_PCICORE',
#   'PINCTRL_VT8500',
#   'SMSC911X_ARCH_HOOKS',
#   'ZCRYPT',
#   'GENERIC_LSHRDI3',
#   'USB_G_DBGP_PRINTK',
#   'ARCH_HAS_ASYNC_TX_FIND_CHANNEL',
#   'MVEBU_PIC',
#   'I2C_NOMADIK',
#   'RTC_DRV_BFIN',
#   'SPI_S3C24XX',
#   'I2C_CPM',
#   'BACKLIGHT_LOCOMO',
#   'PINCTRL_SUN50I_H5',
#   'DRM_HISI_KIRIN',
#   'LEDS_PM8058',
#   'MPSC',
#   'GENERIC_SCHED_CLOCK',
#   'KEYBOARD_PXA930_ROTARY',
#   'AT91_CF',
#   'SCC_DELAY',
#   'LANTIQ_ETOP',
#   'FB_FM2',
#   'ARMADA_370_XP_IRQ',
#   'MODULE_SIG_SHA224',
#   'HAS_DMA',
#   'PCMCIA_SYM53C500',
#   'PINCTRL_ARMADA_37XX',
#   'DRM_EXYNOS7_DECON',
#   'ARCH_TEGRA_210_SOC',
#   'TI_DAVINCI_CPDMA',
#   'RESET_A10SR',
#   'XILINX_AXI_EMAC',
#   'A2065',
#   'AX88796',
#   'SCx200',
#   'MACE',
#   'SERIAL_MSM_CONSOLE',
#   'M686',
#   'INLINE_READ_UNLOCK_BH',
#   'BATTERY_IPAQ_MICRO',
#   'ARCH_INLINE_READ_LOCK_BH',
#   'DRM_EXYNOS_VIDI',
#   'BFIN_WDT',
#   'ARCH_DISCONTIGMEM_ENABLE',
#   'INTEL_IOP_ADMA',
#   'TI_EMIF',
#   'FB_OMAP2_PANEL_TPO_TD028TTEC1',
#   'PATA_BK3710',
#   'DASD_PROFILE',
#   'SPARSEMEM',
#   'FB_SH7760',
#   'HVC_OLD_HVSI',
#   'PINCTRL_SUN8I_H3',
#   'XEN_ACPI_HOTPLUG_CPU',
#   'ARM_SMMU',
#   'MOUSE_NAVPOINT_PXA27x',
#   'ARCH_WANT_GENERAL_HUGETLB',
#   'EDAC_PPC4XX',
#   'HAVE_PERF_REGS',
#   'I2C_HYDRA',
#   'USB_OHCI_HCD_S3C2410',
#   'QCOM_L2_PMU',
#   'USB_OHCI_BIG_ENDIAN_MMIO',
#   'RTC_DRV_AU1XXX',
#   'SCSI_POWERTECSCSI',
#   'MTD_NAND_SOCRATES',
#   'B43LEGACY_PCICORE_AUTOSELECT',
#   'FB_OMAP2_DSS',
#   'EDAC_ALTERA_USB',
#   'FB_CT65550',
#   'AHCI_DA850',
#   'USB_CNS3XXX_EHCI',
#   'BACKLIGHT_IPAQ_MICRO',
#   'HAVE_EFFICIENT_UNALIGNED_ACCESS',
#   'BLK_DEV_4DRIVES',
#   'SUNVNET',
#   'SUN4I_EMAC',
#   'INLINE_READ_LOCK_BH',
#   'MODULE_SIG_SHA512',
#   'VLYNQ_DEBUG',
#   'AT_XDMAC',
#   'PWM_SPEAR',
#   'RADIO_RTRACK2',
#   'VIDEO_BLACKFIN_PPI',
#   'PPC_BESTCOMM_FEC',
#   'PINCTRL_MESON_GXBB',
#   'SERIAL_VR41XX_CONSOLE',
#   'PCI_GOOLPC',
#   'ATMEL_TCB_CLKSRC',
#   'HOTPLUG_PCI_IBM',
#   'KASAN_INLINE',
#   'SND_PXA2XX_SOC_E740',
#   'HSEM_U8500',
#   'SCSI_CUMANA_2',
#   'HAVE_CONTEXT_TRACKING',
#   'SPARC_US2E_CPUFREQ',
#   'SERIAL_ETRAXFS',
#   'MODULES_USE_ELF_REL',
#   'PARTITION_PERCPU',
#   'PSERIES_CPUIDLE',
#   'SND_SOC_TTC_DKB',
#   'I82365',
#   'PATA_PXA',
#   'ARCH_USES_GETTIMEOFFSET',
#   'ARCH_INLINE_READ_TRYLOCK',
#   'QCOM_SMD_RPM',
#   'BLK_DEV_HT6560B',
#   'CXL',
#   'SBC7240_WDT',
#   'PINCTRL_SPEAR',
#   '53C700_LE_ON_BE',
#   'FB_APOLLO',
#   'SERIO_Q40KBD',
#   'INPUT_PMIC8XXX_PWRKEY',
#   'SND_SOC_SAMSUNG_S3C24XX_UDA134X',
#   'INITRAMFS_COMPRESSION_LZO',
#   'OMAP2_DSS',
#   'ARM_ETHER1',
#   'ROCKCHIP_IOMMU',
#   'NET_BFIN',
#   'MONWRITER',
#   'SND_SOC_ZYLONITE',
#   'BLK_DEV_UMC8672',
#   'SND_DA830_SOC_EVM',
#   'MODULES_TREE_LOOKUP',
#   'IRQ_DOMAIN',
#   'FB_BFIN_7393',
#   'USB_EHCI_HCD_PPC_OF',
#   'CLKSRC_IMX_TPM',
#   'IUCV',
#   'FB_S3C2410',
#   'OCTEON_WDT',
#   'SCSI_LASI700',
#   'SERIO_RPCKBD',
#   'PINCTRL_PFC_R8A7791',
#   'SND_AOA_TOONIE',
#   'SOC_REALVIEW',
#   'NTSC_640x480',
#   'IBM_EMAC_ZMII',
#   'CLKSRC_LPC32XX',
#   'INLINE_WRITE_LOCK_IRQ',
#   'HW_RANDOM_BCM63XX',
#   'HAVE_ARCH_TRANSPARENT_HUGEPAGE_PUD',
#   'MTD_AFS_PARTS',
#   'USB_G_DBGP_SERIAL',
#   'PCI_GOANY',
#   'VEXPRESS_CONFIG',
#   'TRANSPARENT_HUGEPAGE_MADVISE',
#   'TI_SCI_PM_DOMAINS',
#   'IBMVETH',
#   'PINCTRL_COH901',
#   'IXP4XX_WATCHDOG',
#   'VIDEO_OMAP2_VOUT_VRFB',
#   'MCF8390',
#   'UCC_GETH',
#   'PINCTRL_IMX7ULP',
#   'DRM_ETNAVIV',
#   'CMT_SPEECH',
#   'DRM_OMAP_ENCODER_OPA362',
#   'X86',
#   'MFD_DAVINCI_VOICECODEC',
#   'HAVE_DYNAMIC_FTRACE_WITH_REGS',
#   'SCSI_SNI_53C710',
#   'BLK_DEV_SWIM',
#   'LOGO_SUPERH_MONO',
#   'NET_NETX',
#   'SPI_COLDFIRE_QSPI',
#   'SERIAL_PXA',
#   'MTD_NAND_JZ4740',
#   'EDAC_I82443BXGX',
#   'X86_PAE',
#   'MTD_NAND_BRCMNAND',
#   'SUNBMAC',
#   'NE2000',
#   'PSTORE_LZO_COMPRESS',
#   'ARM_GIC',
#   'X86_SPEEDSTEP_SMI',
#   'SND_PXA2XX_SOC_IMOTE2',
#   'MMC_QCOM_DML',
#   'OF_NUMA',
#   'LEGACY_VSYSCALL_NONE',
#   'ARM_S3C2416_CPUFREQ',
#   'IDE_LEGACY',
#   'PATA_ISAPNP',
#   'ARM_GIC_V3',
#   'MVEBU_ICU',
#   'SCSI_SYM53C416',
#   'SERIAL_PIC32_CONSOLE',
#   'B43_BUSES_BCMA',
#   'SND_MIPS',
#   'SND_SOC_IMX_PCM_FIQ',
#   'MTK_SMI',
#   'HVC_OPAL',
#   'KEYBOARD_AMIGA',
#   'NTSC_YCBCR',
#   'EDAC_PASEMI',
#   'SND_DM6467_SOC_EVM',
#   'PTP_1588_CLOCK_IXP46X',
#   'CPU_SUP_CYRIX_32',
#   'SND_SOC_IMX_SSI',
#   'SND_MMP_SOC_BROWNSTONE',
#   'DRM_EXYNOS',
#   'SND_SOC_DB1200',
#   'IOP_WATCHDOG',
#   'PINCTRL_BF60x',
#   'FB_WM8505',
#   'BCMA_DRIVER_PCI_HOSTMODE',
#   'USB_S3C_HSUDC',
#   'NOKIA_MODEM',
#   'SND_SOC_MEDIATEK',
#   'FB_OMAP2_DSS_SDI',
#   'POWER_RESET_XGENE',
#   'BACKLIGHT_EP93XX',
#   'ARM_TEGRA124_CPUFREQ',
#   'SPI_PL022',
#   'EL3',
#   'SERIAL_BFIN_UART3',
#   'REGULATOR_TI_ABB',
#   'ARCH_INLINE_SPIN_UNLOCK',
#   'CLOCKSOURCE_WATCHDOG',
#   'DEBUG_NOMMU_REGIONS',
#   'ARCH_HAS_UACCESS_FLUSHCACHE',
#   'OMAP2_DSS_DSI',
#   'USB_S3C2410',
#   'ARCH_INLINE_SPIN_UNLOCK_IRQRESTORE',
#   'I2C_CADENCE',
#   'HAVE_64BIT_ALIGNED_ACCESS',
#   'BACKLIGHT_ATMEL_LCDC',
#   'SND_SH7760_AC97',
#   'SERIO_SA1111',
#   'HOTPLUG_PCI_RPA_DLPAR',
#   'SERIAL_SGI_IOC4',
#   'TOUCHSCREEN_WM97XX_MAINSTONE',
#   'USB_G_NCM',
#   'SPI_ATH79',
#   'SND_SOC_PHYCORE_AC97',
#   'DMA_NOOP_OPS',
#   'SNI_82596',
#   'AHCI_OCTEON',
#   'MMC_AU1X',
#   'MTD_NAND_OMAP_BCH',
#   'MOUSE_PS2_OLPC',
#   'ARCH_INLINE_SPIN_LOCK_BH',
#   'JOYSTICK_AMIGA',
#   'SND_SOC_TXX9ACLC_GENERIC',
#   'FB_OLPC_DCON',
#   'WINDFARM_PM91',
#   'QCOM_ADSP_PIL',
#   'BERLIN2_ADC',
#   'KEYBOARD_HIL_OLD',
#   'ORION_IRQCHIP',
#   'QCOM_SMEM',
#   'LOGO_MAC_CLUT224',
#   'ARM_SCPI_CPUFREQ',
#   'STACKTRACE_SUPPORT',
#   'MTD_NAND_FSL_UPM',
#   'LBDAF',
#   'SND_ATMEL_AC97C',
#   '3C515',
#   'FSL_DPAA2_ETH',
#   'SND_AD1816A',
#   'AGP_HP_ZX1',
#   'RTC_DRV_PUV3',
#   'FAULT_INJECTION_STACKTRACE_FILTER',
#   'MODULE_SIG_SHA384',
#   'SND_SOC_AU1XI2SC',
#   'PINCTRL_SUN5I',
#   'GENERIC_IDLE_POLL_SETUP',
#   'VM86',
#   'IBM_EMAC_RGMII',
#   'MTD_NAND_PASEMI',
#   'USB_GADGET_TARGET',
#   'HAVE_GENERIC_DMA_COHERENT',
#   'I2C_XGENE_SLIMPRO',
#   'TEGRA_MC',
#   'OSF4_COMPAT',
#   'I2C_ACORN',
#   'SERIAL_8250_MT6577',
#   'FB_ARMCLCD',
#   'RC32434_WDT',
#   'QCOM_RPMCC',
#   'PCIE_QCOM',
#   'TEST_ASYNC_DRIVER_PROBE',
#   'PNPBIOS_PROC_FS',
#   'MCP_SA11X0',
#   'SND_PXA2XX_SOC_TOSA',
#   'ARCH_SUPPORTS_UPROBES',
#   'ARCH_HAS_ZONE_DEVICE',
#   'SND_PXA2XX_SOC_AC97',
#   'GREYBUS_CAMERA',
#   'CLKSRC_EFM32',
#   'HAVE_ARCH_KASAN',
#   'SND_PPC',
#   'PMAC_RACKMETER',
#   'VEXPRESS_SYSCFG',
#   'DCACHE_WORD_ACCESS',
#   'USB_OHCI_SH',
#   'PINCTRL_TZ1090',
#   'LOONGSON1_WDT',
#   'ARMADA_CP110_SYSCON',
#   'DRM_EXYNOS_FIMC',
#   'GENERIC_CALIBRATE_DELAY',
#   'RTC_DRV_LOONGSON1',
#   'MTD_VMU',
#   'PREEMPT_RCU',
#   'PWM_TIPWMSS',
#   'LEGACY_VSYSCALL_EMULATE',
#   'GCOV_FORMAT_4_7',
#   'SND_SOC_MPC5200_AC97',
#   'PWM_OMAP_DMTIMER',
#   'HAVE_FB_ATMEL',
#   'WIZNET_BUS_DIRECT',
#   'ARM_KS8695_ETHER',
#   'SCSI_ZALON',
#   'USB_PXA25X_SMALL',
#   'USB_EHCI_ATH79',
#   'CLOCKSOURCE_VALIDATE_LAST_CYCLE',
#   'AUDIT_GENERIC',
#   'DASD_FBA',
#   'PINCTRL_SH_PFC',
#   'USB_ULPI_VIEWPORT',
#   'SND_SOC_UX500_MACH_MOP500',
#   'SERIAL_TXX9_STDSERIAL',
#   'MOUSE_LOGIBM',
#   'PINCTRL_IMX51',
#   'SENSORS_AB8500',
#   'BCM47XX_NVRAM',
#   'SERIAL_BFIN_SPORT2_UART',
#   'QCOM_SCM_64',
#   'ADB_PMU_LED_DISK',
#   'MVEBU_DEVBUS',
#   'PCIE_MEDIATEK',
#   'ODD_RT_SIGACTION',
#   'ST_SLIM_REMOTEPROC',
#   'DA8XX_MSTPRI',
#   'SND_SOC_SH4_SSI',
#   'DRM_MSM_DSI_28NM_PHY',
#   'REGULATOR_QCOM_RPM',
#   'PHY_EXYNOS5250_SATA',
#   'QCOM_CLK_RPM',
#   'DRM_ARMADA',
#   'SENSORS_JZ4740',
#   'WATCHDOG_CP1XXX',
#   'MPENTIUMIII',
#   'SND_BF5XX_SOC_SPORT',
#   'AB8500_BM',
#   'MAC_SCSI',
#   'MMP_PANEL_TPOHVGA',
#   'EFI_PCDP',
#   'SND_PXA910_SOC',
#   'BATTERY_TOSA',
#   'MMP_DISP_SPI',
#   'CRC32_SARWATE',
#   'PINCTRL_SUN8I_A33',
#   'ISDN_DRV_AVMB1_B1ISA',
#   'ANSLCD',
#   'SPI_LOOPBACK_TEST',
#   'EDAC_HIGHBANK_MC',
#   'PINCTRL_PFC_SH73A0',
#   'TCIC',
#   'FSL_BMAN_TEST',
#   'PAL',
#   'PWM_TEGRA',
#   'ARM_ETHER3',
#   'USB_EHCI_MXC',
#   'SCSI_IBMVSCSIS',
#   'HAVE_KPROBES',
#   'NOHIGHMEM',
#   'SND_AOA_FABRIC_LAYOUT',
#   'DMASOUND_ATARI',
#   'ARCH_HAS_KCOV',
#   'ARM_S3C_CPUFREQ',
#   'SND_AICA',
#   'ARCH_WANT_BATCHED_UNMAP_TLB_FLUSH',
#   'MMC_SDHCI_ST',
#   'PHY_MIPHY28LP',
#   'DRM_IMX_PARALLEL_DISPLAY',
#   'STE_DMA40',
#   'RADIO_TERRATEC',
#   'HISILICON_IRQ_MBIGEN',
#   'SND_SB8_DSP',
#   'LOGO_SUN_CLUT224',
#   'PCIE_XILINX_NWL',
#   'MFD_ASIC3',
#   'PINCTRL_AT91',
#   'COMMON_CLK_MESON8B',
#   'GENERIC_SMP_IDLE_THREAD',
#   'SERIAL_MPSC_CONSOLE',
#   'WINDFARM_PM72',
#   'X86_ESPFIX32',
#   'CRYPTO_DEV_FSL_CAAM_AHASH_API',
#   'WIZNET_BUS_INDIRECT',
#   'FB_PXA_OVERLAY',
#   'ARCH_DISCONTIGMEM_DEFAULT',
#   'DRM_OMAP_CONNECTOR_DVI',
#   'FB_AMIGA_ECS',
#   'SERIAL_SB1250_DUART_CONSOLE',
#   'KEYBOARD_SNVS_PWRKEY',
#   'SRAM_EXEC',
#   'MODULE_REL_CRCS',
#   'CLKSRC_EXYNOS_MCT',
#   'INDYDOG',
#   'SND_SOC_BFIN_EVAL_ADAU1373',
#   'FB_OMAP4_DSS_HDMI',
#   'SPI_ATMEL_QUADSPI',
#   'ADB_MACII',
#   'AUDIT_ARCH',
#   'HYSDN',
#   'I2C_IOP3XX',
#   'PROFILE_ALL_BRANCHES',
#   'IMX_GPCV2',
#   'ARCH_CLOCKSOURCE_DATA',
#   'QE_TDM',
#   'CPU_FREQ_CBE',
#   'CLPS711X_IRQCHIP',
#   'LEGACY_VSYSCALL_NATIVE',
#   'ARM_ZYNQ_CPUIDLE',
#   'BFIN_JTAG_COMM',
#   'PCIEASPM_PERFORMANCE',
#   'SERIAL_IP22_ZILOG',
#   'PCI_LAYERSCAPE',
#   'HW_RANDOM_MXC_RNGA',
#   'ARCH_INLINE_READ_LOCK',
#   'OMAP_DSS_BASE',
#   'TN3270_FS',
#   'CMA_SIZE_SEL_MIN',
#   'PCI_TEGRA',
#   'ARM_KIRKWOOD_CPUIDLE',
#   'SCSI_IBMVFC',
#   'MMC_S3C',
#   'NVMEM_SUNXI_SID',
#   'CPU_SUP_TRANSMETA_32',
#   'AB8500_CORE',
#   'VFIO_PLATFORM',
#   'ARCH_WANT_HUGE_PMD_SHARE',
#   'DEBUG_IMR_SELFTEST',
#   'FS_ENET',
#   'MGEODEGX1',
#   'SA1100_FIR',
#   'GENERIC_CMPDI2',
#   'MCORE2',
#   'DMA_SUN4I',
#   'CRYPTO_CRCT10DIF_VPMSUM',
#   'B43_BUSES_SSB',
#   'SCTP_DEFAULT_COOKIE_HMAC_NONE',
#   'HAVE_ATOMIC_IOMAP',
#   'ARCH_SUPPORTS_NUMA_BALANCING',
#   'BLK_DEV_IDE_PMAC_ATA100FIRST',
#   'MTD_CFI_FLAGADM',
#   'NO_GENERIC_PCI_IOPORT_MAP',
#   'USB_TI_CPPI_DMA',
#   'DA_TTY',
#   'PHY_QCOM_IPQ806X_SATA',
#   'MMC_WMT',
#   'HANDLE_DOMAIN_IRQ',
#   'QCOM_Q6V5_PIL',
#   'TOUCHSCREEN_LPC32XX',
#   'PWM_EP93XX',
#   'SND_BF5XX_SOC_I2S',
#   'SPEAKUP_SYNTH_DECPC',
#   'INPUT_IXP4XX_BEEPER',
#   'ARCH_HAS_ADD_PAGES',
#   'SERIAL_NETX_CONSOLE',
#   'MTD_NAND_MLC_LPC32XX',
#   'FSL_IFC',
#   'AT91_ADC',
#   'IPMI_POWERNV',
#   'SND_AOA_TAS',
#   'QCOM_CLK_SMD_RPM',
#   'AMBA_PL08X',
#   'INPUT_SGI_BTNS',
#   'ARM_GIC_V2M',
#   'PINCTRL_IMX35',
#   'MTD_NAND_SUNXI',
#   'HZ_100',
#   'LEDS_LOCOMO',
#   'PINCTRL_SAMSUNG',
#   'OMAP_SSI',
#   'SERIAL_ICOM',
#   'PINCTRL_SUN4I_A10',
#   'PINCTRL_BF54x',
#   'MIPS_PLATFORM_DEVICES',
#   'INLINE_WRITE_TRYLOCK',
#   'SND_SOC_SAMSUNG_RX1950_UDA1380',
#   'ZONE_DMA32',
#   'PERCPU_TEST',
#   'ARCH_TEGRA_2x_SOC',
#   'PNPBIOS',
#   'X86_REBOOTFIXUPS',
#   'MIXCOMWD',
#   'QCOM_WCNSS_PIL',
#   'USB_OHCI_HCD_AT91',
#   'SCSI_SUNESP',
#   'MTD_NAND_S3C2410_DEBUG',
#   'STA2X11_VIP',
#   'PHY_SUN4I_USB',
#   'PINCTRL_EXYNOS5440',
#   'SAMPLE_HW_BREAKPOINT',
#   'ARM_SPE_PMU',
#   'IBMVNIC',
#   'AGP_UNINORTH',
#   'TEGRA_BPMP_THERMAL',
#   'ARM_BIG_LITTLE_CPUIDLE',
#   'POWER_RESET_AXXIA',
#   'FB_I810_GTF',
#   'MTD_NAND_QCOM',
#   'FTMAC100',
#   'ST_THERMAL_SYSCFG',
#   'ARMADA_XP_CLK',
#   'EDAC_ALTERA_SDMMC',
#   'USB_OHCI_HCD_SPEAR',
#   'SND_SBAWE_SEQ',
#   'MAC8390',
#   'RENESAS_INTC_IRQPIN',
#   'DA8XX_DDRCTL',
#   'SELECT_MEMORY_MODEL',
#   'SND_SOC_UX500_PLAT_DMA',
#   'FB_Q40',
#   'IO_DELAY_NONE',
#   'THREAD_INFO_IN_TASK',
#   'SERIAL_BFIN_SPORT1_UART_CTSRTS',
#   'BLK_DEV_IDE_AU1XXX',
#   'RTC_DRV_TWL92330',
#   'TI_KEYSTONE_NETCP',
#   'FB_BW2',
#   'ST_REMOTEPROC',
#   'SND_SOC_AU1XPSC_AC97',
#   'DRM_EXYNOS_HDMI',
#   'XGENE_SLIMPRO_MBOX',
#   'MVEBU_CLK_CPU',
#   'ARM_S3C2440_CPUFREQ',
#   'DRM_HDLCD',
#   'DRM_MALI_DISPLAY',
#   'FB_ATMEL',
#   'USB_FUSB300',
#   'HMC_DRV',
#   'MMC_MESON_GX',
#   'FB_WMT_GE_ROPS',
#   'GENERIC_IRQ_MATRIX_ALLOCATOR',
#   'SND_MIRO',
#   'THERM_WINDTUNNEL',
#   'MMP_DISP',
#   'PCI_HOST_THUNDER_PEM',
#   'PWM_BERLIN',
#   'MX3_IPU',
#   'FB_S3C2410_DEBUG',
#   'ULTRA',
#   'MOUSE_PC110PAD',
#   'PINCTRL_SPEAR3XX',
#   'ICST',
#   'USB_FUNCTIONFS',
#   'KS8695_WATCHDOG',
#   'S390_CCW_IOMMU',
#   'KEYSTONE_TIMER',
#   'GPIO_VF610',
#   'USB_ETH_EEM',
#   'HAVE_OPROFILE',
#   'DEFAULT_SFQ',
#   'SPI_ADI_V3',
#   'USB_OHCI_HCD_OMAP1',
#   'GENERIC_IRQ_IPI',
#   'NET_VENDOR_XILINX',
#   'OMPIC',
#   'LEDS_FSG',
#   'LANTIQ_WDT',
#   'FB_NUC900',
#   'RASPBERRYPI_POWER',
#   'CLKSRC_NPS',
#   'NET_VENDOR_NUVOTON',
#   'CLONE_BACKWARDS3',
#   'SND_SOC_AU1XAUDIO',
#   'ARCH_FLATMEM_ENABLE',
#   'CPU_FREQ_DEFAULT_GOV_USERSPACE',
#   'HISAX_MIC',
#   'RTC_DRV_RS5C313',
#   'DEBUG_SLAB_LEAK',
#   'MMC_TMIO',
#   'PCI_IMX6',
#   'SIR_BFIN_PIO',
#   'DRM_OMAP_PANEL_DSI_CM',
#   'UCC_FAST',
#   'USB_TI_CPPI41_DMA',
#   'PINCTRL_GEMINI',
#   'INLINE_WRITE_LOCK_IRQSAVE',
#   'OR1K_PIC',
#   'RTL8192U',
#   'LTE_GDM724X',
#   'ARM_S3C24XX_CPUFREQ_IODEBUG',
#   'MFD_T7L66XB',
#   'IIO_BFIN_TMR_TRIGGER',
#   'ARCH_TEGRA_3x_SOC',
#   'SND_AOA_SOUNDBUS_I2S',
#   'SERIAL_BFIN_SPORT0_UART',
#   'POWER_RESET_AT91_POWEROFF',
#   'ARM_KIRKWOOD_CPUFREQ',
#   'VIRT_CPU_ACCOUNTING',
#   'GENERIC_CPU_VULNERABILITIES',
#   'VIRT_CPU_ACCOUNTING_NATIVE',
#   'SFP',
#   'NWBUTTON',
#   'XILINX_INTC',
#   'X86_INTEL_USERCOPY',
#   'DT_IDLE_STATES',
#   'MENELAUS',
#   'PINCTRL_SUN8I_A23',
#   'VMCP',
#   'MTD_LANTIQ',
#   'CAN_BFIN',
#   'PCI_LOCKLESS_CONFIG',
#   'PHY_RCAR_GEN2',
#   'SERIAL_MCF',
#   'SERIAL_PMACZILOG_CONSOLE',
#   'HAS_IOPORT_MAP',
#   'DRM_RCAR_VSP',
#   'PCIE_HISI_STB',
#   'EISA_VLB_PRIMING',
#   'LUSTRE_FS',
#   'QORIQ_CPUFREQ',
#   'FB_I810',
#   'CRYPTO_DEV_UX500_DEBUG',
#   'FB_MBX_DEBUG',
#   'CAN_RCAR',
#   'ELAN_CPUFREQ',
#   'REGULATOR_QCOM_SMD_RPM',
#   'CRYPTO_MD5_PPC',
#   'HW_RANDOM_OMAP',
#   'SGI_NEWPORT_CONSOLE',
#   'ZX2967_WATCHDOG',
#   'EP93XX_ADC',
#   'MTD_NAND_FSL_ELBC',
#   'KEYBOARD_SPEAR',
#   'HAVE_RCU_TABLE_FREE',
#   'INLINE_READ_UNLOCK_IRQRESTORE',
#   'DMASCC',
#   'UCC',
#   'TEST_USER_COPY',
#   'FB_DA8XX',
#   'PINCTRL_PISTACHIO',
#   'USB_EHCI_HCD_AT91',
#   'EEPROM_DIGSY_MTC_CFG',
#   'RTC_DRV_SIRFSOC',
#   'TEST_STATIC_KEYS',
#   'KORINA',
#   'SYSCTL_ARCH_UNALIGN_NO_WARN',
#   'PCMCIA_SA1100',
#   'CPU_FREQ_DEFAULT_GOV_ONDEMAND',
#   'TILE_SROM',
#   'SERIAL_MESON',
#   'SAMPLE_SECCOMP',
#   'WINDFARM_PM112',
#   'SH_CPU_FREQ',
#   'PIC32_EVIC',
#   'SND_SOC_POWERPC_DMA',
#   'HAVE_KERNEL_BZIP2',
#   'I2C_PMCMSP',
#   'ARCH_INLINE_WRITE_LOCK_IRQ',
#   'TEGRA_IOMMU_GART',
#   'GPIO_OCTEON',
#   'PATA_FALCON',
#   'SND_SOC_SAMSUNG_NEO1973_WM8753',
#   'QCOM_SMP2P',
#   'GPIO_MM_LANTIQ',
#   'SERIAL_BFIN',
#   'CRYPTO_ACOMP',
#   'ARCH_USE_CMPXCHG_LOCKREF',
#   'SND_PXA2XX_SOC_E800',
#   'FB_OMAP2_PANEL_SHARP_LS037V7DW01',
#   'X86_INTEL_QUARK',
#   'PCMCIA_AHA152X',
#   'ARCH_WEAK_RELEASE_ACQUIRE',
#   'SND_CMI8330',
#   'USB_ZERO',
#   'STI_RESET_SYSCFG',
#   'I2C_PXA_SLAVE',
#   'THERMAL_DEFAULT_GOV_POWER_ALLOCATOR',
#   'HWSPINLOCK_SIRF',
#   'RTC_MC146818_LIB',
#   'ATARI_KBD_CORE',
#   'FB_OMAP2_ENCODER_TFP410',
#   'M586TSC',
#   'WDT_MTX1',
#   'MFD_TC6387XB',
#   'ARCH_ENABLE_MEMORY_HOTPLUG',
#   'SERIAL_21285_CONSOLE',
#   'SCSI_ARXESCSI',
#   'MFD_DB8500_PRCMU',
#   'TEST_BPF',
#   'FB_VALKYRIE',
#   'MTD_ONENAND_SAMSUNG',
#   'CRYPTO_DEV_FSL_CAAM_JR',
#   'XPS_USB_HCD_XILINX',
#   'VERSATILE_FPGA_IRQ',
#   'ARM_SPEAR_CPUFREQ',
#   'RADIO_MIROPCM20',
#   'SCSI_EATA_PIO',
#   'USB_PXA25X',
#   'HYDRA',
#   'DISCONTIGMEM',
#   'MAC89x0',
#   'HI6220_MBOX',
#   'TEGRA_HOST1X',
#   'X86_ANCIENT_MCE',
#   'HAVE_IRQ_EXIT_ON_IRQ_STACK',
#   'DRM_SUN4I_HDMI_CEC',
#   'BVME6000_SCSI',
#   'DRM_SHMOBILE',
#   'WATCHDOG_RTAS',
#   'AUTO_IRQ_AFFINITY',
#   'I2C_PXA_PCI',
#   'PMAC_MEDIABAY',
#   'CPU_PM',
#   'VMLOGRDR',
#   'MTD_NAND_OMAP2',
#   'RTC_LIB',
#   'M586MMX',
#   'STRICT_KERNEL_RWX',
#   'ARM_CCN',
#   'HAVE_KERNEL_LZ4',
#   'HW_RANDOM_XGENE',
#   'PWM_BRCMSTB',
#   'GENERIC_EARLY_IOREMAP',
#   'BCM47XX_SPROM',
#   'PCI_XGENE',
#   'CRYPTO_SHA1_OCTEON',
#   'S390_VMUR',
#   'TS_NBUS',
#   'AFIUCV',
#   'PCI_RCAR_GEN2',
#   'I2C_PASEMI',
#   'PWM_MXS',
#   'PCIE_SPEAR13XX',
#   'VMSPLIT_2G_OPT',
#   'SND_ATMEL_SOC_TSE850_PCM5142',
#   'X86_BIGSMP',
#   'BMAC',
#   'ARCH_INLINE_READ_LOCK_IRQSAVE',
#   'BINFMT_SHARED_FLAT',
#   'SND_BF5XX_I2S',
#   'SUNVDC',
#   'CRYPTO_DEV_GEODE',
#   'ARCH_WANT_NUMA_VARIABLE_LOCALITY',
#   'CRYPTO_DEV_NX_COMPRESS_POWERNV',
#   'HAVE_ARCH_HUGE_VMAP',
#   'GPIO_ALTERA_A10SR',
#   'SERIAL_SA1100',
#   'QCOM_WCNSS_CTRL',
#   'HW_RANDOM_BCM2835',
#   'GPIO_VR41XX',
#   'FB_OMAP2_ENCODER_TPD12S015',
#   'DRM_MESON',
#   'AHCI_ST',
#   'EFI_ARMSTUB',
#   'SND_SOC_MT2701_CS42448',
#   'INSTRUCTION_DECODER',
#   'MINIX_FS_NATIVE_ENDIAN',
#   'SND_SUN_DBRI',
#   'USB_G_NOKIA',
#   'SERIAL_BFIN_SPORT3_UART_CTSRTS',
#   'ARCH_DISCARD_MEMBLOCK',
#   'ARCH_SUPPORTS_DEFERRED_STRUCT_PAGE_INIT',
#   'SPI_AU1550',
#   'HISAX_ASUSCOM',
#   'PCI_DRA7XX_HOST',
#   'PWM_IMX',
#   'ROCKCHIP_TIMER',
#   'TWL4030_USB',
#   'SERIAL_PIC32',
#   'CRYPTO_SHA512_OCTEON',
#   'TC35815',
#   'MTD_MS02NV',
#   'BLK_DEV_MAC_IDE',
#   'ARCH_SUPPORTS_DEBUG_PAGEALLOC',
#   'SND_PXA2XX_AC97',
#   'HAVE_EBPF_JIT',
#   'BFIN_SIR2',
#   'FSL_ERRATUM_A008585',
#   'FB_G364',
#   'X86_IO_APIC',
#   'OLD_SIGSUSPEND',
#   'SND_SOC_NUC900EVB',
#   'PINCTRL_PFC_R8A7779',
#   'IRQ_PREFLOW_FASTEOI',
#   'DRM_ATMEL_HLCDC',
#   'HIGHMEM64G',
#   'I2C_MPC',
#   'X86_32_IRIS',
#   'ROCKCHIP_DW_MIPI_DSI',
#   'CLKSRC_ARM_GLOBAL_TIMER_SCHED_CLOCK',
#   'DRM_MESON_DW_HDMI',
#   'INITRAMFS_COMPRESSION_BZIP2',
#   'I2C_SPRD',
#   'SND_SOC_TXX9ACLC_AC97',
#   'HISAX_AVM_A1',
#   'SAMPLE_LIVEPATCH',
#   'AX88796_93CX6',
#   'ORION_WATCHDOG',
#   'CRYPTO_SERPENT_SSE2_586',
#   'KEYBOARD_TEGRA',
#   'RT2X00_LIB_SOC',
#   'PINCTRL_MESON_GXL',
#   'DEFAULT_CODEL',
#   'ARCH_HAS_TICK_BROADCAST',
#   'SGI_TIOCX',
#   'ISA',
#   'TN3270_TTY',
#   'CRYPTO_CRC32_S390',
#   'SND_SOC_MT8173_MAX98090',
#   'DRM_STM',
#   'SERIAL_BFIN_PIO',
#   'LS_SCFG_MSI',
#   'ARCH_OPTIONAL_KERNEL_RWX_DEFAULT',
#   'CCWGROUP',
#   'TWL6030_USB',
#   'PINCTRL_PFC_SH7264',
#   'ARCH_HAS_CACHE_LINE_SIZE',
#   'HWSPINLOCK_OMAP',
#   'POWERNV_OP_PANEL',
#   'HAVE_DEBUG_KMEMLEAK',
#   'LTPC',
#   'OMAP2_VRFB',
#   'ARM_PSCI_CHECKER',
#   'SENSORS_AMS_PMU',
#   'SND_GSC',
#   'USB_UHCI_BIG_ENDIAN_DESC',
#   'MMIOTRACE_TEST',
#   'HW_RANDOM_PIC32',
#   'QETH_IPV6',
#   'SND_WSS_LIB',
#   'MOUSE_ATIXL',
#   'HZ_250',
#   'PINCTRL_PFC_SH7734',
#   'MVME147_NET',
#   'IMA_DEFAULT_HASH_SHA512',
#   'CLKSRC_I8253',
#   'FB_OMAP2_DSS_VENC',
#   'MMC_SDHCI_CNS3XXX',
#   'ISP1301_OMAP',
#   'QCOM_SCM_32',
#   'LCD_HP700',
#   'DRM_EXYNOS_GSC',
#   'RTC_DRV_DS17285',
#   'FB_PXA168',
#   'POWERNV_CPUIDLE',
#   'VIDEO_BLACKFIN_CAPTURE',
#   'X86_LONGRUN',
#   'LOGO_SGI_CLUT224',
#   'HWSPINLOCK_SPRD',
#   'IMX_REMOTEPROC',
#   ...],
#  420: ['LCS',
#   'ATMEL_TCLIB',
#   'ARCH_BINFMT_ELF_STATE',
#   'UIO_FSL_ELBC_GPCM_NETX5152',
#   'ARCH_ENABLE_SPLIT_PMD_PTLOCK',
#   'PINCTRL_KIRKWOOD',
#   'PCI_GOMMCONFIG',
#   'PARPORT_MFC3',
#   'ARM_PMU_ACPI',
#   'PHY_MTK_TPHY',
#   'DRM_MSM',
#   'HAVE_EXIT_THREAD',
#   'FB_OLPC_DCON_1_5',
#   'USB_FUNCTIONFS_GENERIC',
#   'QE_USB',
#   'SERIAL_8250_EM',
#   'USB_UHCI_BIG_ENDIAN_MMIO',
#   'XILINX_HWICAP',
#   'RENESAS_H8S_INTC',
#   'CLONE_BACKWARDS',
#   'USB_BCM63XX_UDC',
#   'KERNEL_LZ4',
#   'SCLP_ASYNC',
#   'DASD',
#   'HAVE_KERNEL_GZIP',
#   'MK6',
#   'MTD_NAND_CM_X270',
#   'ARM_PMU',
#   'SCSI_IBMVFC_TRACE',
#   'CRYPTO_DEV_UX500_HASH',
#   'RTC_DRV_MXC',
#   'SPI_OMAP_UWIRE',
#   'RTC_DRV_AB8500',
#   'SERIAL_MPSC',
#   'HAVE_KVM_VCPU_ASYNC_IOCTL',
#   'PINCTRL_IMX6SX',
#   'VIRT_TO_BUS',
#   'TI_EMIF_SRAM',
#   'EDAC_CELL',
#   'SERIAL_8250_OMAP',
#   'CPU_FREQ_PMAC64',
#   'BLK_DEV_IDE_AU1XXX_PIO_DBDMA',
#   'SENSORS_AMS_I2C',
#   'DRM_MSM_DSI_28NM_8960_PHY',
#   'BLK_DEV_IDEDMA_ICS',
#   'PATA_IXP4XX_CF',
#   'SPEAR13XX_PCIE_GADGET',
#   'SAMPLE_VFIO_MDEV_MDPY_FB',
#   'SPI_S3C24XX_FIQ',
#   'OMAP_REMOTEPROC',
#   'SND_DM365_VOICE_CODEC',
#   'FB_MXS',
#   'INTEL_IOMMU_BROKEN_GFX_WA',
#   'TI_CPPI41',
#   'RTC_DRV_OPAL',
#   'PINCTRL_U300',
#   'PINCTRL_IMX6SLL',
#   'TXX9_DMAC',
#   'PINCTRL_TEGRA114',
#   'OMAP_GPMC',
#   'SQUASHFS_FILE_DIRECT',
#   'JZ4740_WDT',
#   'X86_CMOV',
#   'SSB_PCICORE_HOSTMODE',
#   'USB_MUSB_OMAP2PLUS',
#   'PHY_RCAR_GEN3_PCIE',
#   'SERIAL_8250_PXA',
#   'NET_VENDOR_MEDIATEK',
#   'INITRAMFS_COMPRESSION_LZMA',
#   'HISAX_SPORTSTER',
#   'HARDLOCKUP_CHECK_TIMESTAMP',
#   'EDAC_AMD8111',
#   'INGENIC_IRQ',
#   'EDAC_I82860',
#   'SCSI_MESH',
#   'USB_OHCI_HCD_LPC32XX',
#   'RTC_DRV_EFI',
#   'SUN50I_DE2_BUS',
#   'SND_S3C24XX_I2S',
#   'HAVE_COPY_THREAD_TLS',
#   'MMC_DW_ZX',
#   'SERIAL_8250_HUB6',
#   'SERIAL_SUNZILOG',
#   'PINCTRL_ARMADA_38X',
#   'ARCH_INLINE_SPIN_LOCK_IRQSAVE',
#   'PCMCIA_XXS1500',
#   'OLPC',
#   'HISI_PMU',
#   'MFD_JZ4740_ADC',
#   'ATARI_FLOPPY',
#   'PPC_BESTCOMM',
#   'CRYPTO_CRC32C_VPMSUM',
#   'PINCTRL_ARTPEC6',
#   'GPIO_EP93XX',
#   'KCOV_ENABLE_COMPARISONS',
#   'USB_UHCI_SUPPORT_NON_PCI_HC',
#   'DEBUG_PREEMPT',
#   'NET_VENDOR_XSCALE',
#   'RTC_DRV_MXC_V2',
#   'EDAC_MPC85XX',
#   'SA1100_WATCHDOG',
#   'MTD_PISMO',
#   'CONTEXT_TRACKING_FORCE',
#   'CLKSRC_NOMADIK_MTU_SCHED_CLOCK',
#   'PINCTRL_ST',
#   'CLKSRC_IMX_GPT',
#   'SCSI_ACORNSCSI_TAGGED_QUEUE',
#   'PINCTRL_PFC_R8A77990',
#   'PWM_MESON',
#   'SND_S3C2412_SOC_I2S',
#   'ARCH_USE_QUEUED_SPINLOCKS',
#   'ARCH_INLINE_WRITE_LOCK_BH',
#   'PHY_PXA_USB',
#   'OMAP_OCP2SCP',
#   'SERIAL_NETX',
#   'MFD_TMIO',
#   'SPAPR_TCE_IOMMU',
#   'R8822BE',
#   'INPUT_COBALT_BTNS',
#   'ARM_S3C24XX_CPUFREQ',
#   'MIPS_EJTAG_FDC_EARLYCON',
#   'PARPORT_ATARI',
#   'USB_G_MULTI_RNDIS',
#   'CPU_NO_EFFICIENT_FFS',
#   'RTL8192E',
#   'ARCH_THREAD_STACK_ALLOCATOR',
#   'EROFS_FS_ZIP_CACHE_UNIPOLAR',
#   'SND_PXA2XX_LIB_AC97',
#   'SCSI_MAC53C94',
#   'ARM_CCI400_PMU',
#   'USB_OHCI_HCD_PXA27X',
#   'MTK_IOMMU_V1',
#   'X86_USE_3DNOW',
#   'SGI_IOC3_ETH',
#   'INPUT_WISTRON_BTNS',
#   'HW_RANDOM_HISI',
#   'DRM_OMAP_PANEL_LGPHILIPS_LB035Q02',
#   'SERIAL_SUNSU',
#   'GPM1040A0_320X240',
#   'RCU_BOOST',
#   'I2C_STUB',
#   'COMMON_CLK_PXA',
#   'ARM_TI_CPUFREQ',
#   'PINCTRL_VT8500',
#   'SMSC911X_ARCH_HOOKS',
#   'ZCRYPT',
#   'USB_G_DBGP_PRINTK',
#   'ARCH_HAS_ASYNC_TX_FIND_CHANNEL',
#   'MVEBU_PIC',
#   'I2C_NOMADIK',
#   'SPI_S3C24XX',
#   'I2C_CPM',
#   'BACKLIGHT_LOCOMO',
#   'PINCTRL_SUN50I_H5',
#   'DRM_HISI_KIRIN',
#   'MPSC',
#   'GENERIC_SCHED_CLOCK',
#   'KEYBOARD_PXA930_ROTARY',
#   'AT91_CF',
#   'SCC_DELAY',
#   'LANTIQ_ETOP',
#   'FB_FM2',
#   'ARMADA_370_XP_IRQ',
#   'MODULE_SIG_SHA224',
#   'HAS_DMA',
#   'PCMCIA_SYM53C500',
#   'PINCTRL_ARMADA_37XX',
#   'DRM_EXYNOS7_DECON',
#   'ARCH_TEGRA_210_SOC',
#   'RESET_A10SR',
#   'XILINX_AXI_EMAC',
#   'A2065',
#   'SCx200',
#   'MACE',
#   'SERIAL_MSM_CONSOLE',
#   'M686',
#   'INLINE_READ_UNLOCK_BH',
#   'BATTERY_IPAQ_MICRO',
#   'ARCH_INLINE_READ_LOCK_BH',
#   'DRM_EXYNOS_VIDI',
#   'ARCH_DISCONTIGMEM_ENABLE',
#   'INTEL_IOP_ADMA',
#   'TI_EMIF',
#   'PATA_BK3710',
#   'DASD_PROFILE',
#   'FB_SH7760',
#   'SPARSEMEM',
#   'HVC_OLD_HVSI',
#   'PINCTRL_SUN8I_H3',
#   'XEN_ACPI_HOTPLUG_CPU',
#   'ARM_SMMU',
#   'MOUSE_NAVPOINT_PXA27x',
#   'ARCH_WANT_GENERAL_HUGETLB',
#   'EDAC_PPC4XX',
#   'HAVE_PERF_REGS',
#   'I2C_HYDRA',
#   'USB_OHCI_HCD_S3C2410',
#   'QCOM_L2_PMU',
#   'USB_OHCI_BIG_ENDIAN_MMIO',
#   'RTC_DRV_AU1XXX',
#   'SCSI_POWERTECSCSI',
#   'MTD_NAND_SOCRATES',
#   'EDAC_ALTERA_USB',
#   'FB_CT65550',
#   'AHCI_DA850',
#   'USB_CNS3XXX_EHCI',
#   'BACKLIGHT_IPAQ_MICRO',
#   'HAVE_EFFICIENT_UNALIGNED_ACCESS',
#   'SUNVNET',
#   'BLK_DEV_4DRIVES',
#   'SUN4I_EMAC',
#   'INLINE_READ_LOCK_BH',
#   'MODULE_SIG_SHA512',
#   'VLYNQ_DEBUG',
#   'AT_XDMAC',
#   'PWM_SPEAR',
#   'PPC_BESTCOMM_FEC',
#   'PINCTRL_MESON_GXBB',
#   'SERIAL_VR41XX_CONSOLE',
#   'PINCTRL_PFC_R8A77470',
#   'PCI_GOOLPC',
#   'ATMEL_TCB_CLKSRC',
#   'HOTPLUG_PCI_IBM',
#   'KASAN_INLINE',
#   'SND_PXA2XX_SOC_E740',
#   'HSEM_U8500',
#   'SCSI_CUMANA_2',
#   'GCC_PLUGIN_SANCOV',
#   'HAVE_NOP_MCOUNT',
#   'HAVE_CONTEXT_TRACKING',
#   'SPARC_US2E_CPUFREQ',
#   'MODULES_USE_ELF_REL',
#   'PARTITION_PERCPU',
#   'PSERIES_CPUIDLE',
#   'SND_SOC_TTC_DKB',
#   'I82365',
#   'PATA_PXA',
#   'ARCH_USES_GETTIMEOFFSET',
#   'ARCH_INLINE_READ_TRYLOCK',
#   'BLK_DEV_HT6560B',
#   'CXL',
#   'SBC7240_WDT',
#   'PINCTRL_SPEAR',
#   '53C700_LE_ON_BE',
#   'FB_APOLLO',
#   'SERIO_Q40KBD',
#   'SND_SOC_SAMSUNG_S3C24XX_UDA134X',
#   'INITRAMFS_COMPRESSION_LZO',
#   'QCOM_PDC',
#   'OMAP2_DSS',
#   'ARM_ETHER1',
#   'ROCKCHIP_IOMMU',
#   'MONWRITER',
#   'SND_SOC_ZYLONITE',
#   'BLK_DEV_UMC8672',
#   'SND_DA830_SOC_EVM',
#   'MODULES_TREE_LOOKUP',
#   'IRQ_DOMAIN',
#   'USB_EHCI_HCD_PPC_OF',
#   'CLKSRC_IMX_TPM',
#   'IUCV',
#   'FB_S3C2410',
#   'OCTEON_WDT',
#   'SCSI_LASI700',
#   'SERIO_RPCKBD',
#   'PINCTRL_PFC_R8A7791',
#   'SND_AOA_TOONIE',
#   'KRAITCC',
#   'SOC_REALVIEW',
#   'IBM_EMAC_ZMII',
#   'CLKSRC_LPC32XX',
#   'INLINE_WRITE_LOCK_IRQ',
#   'SND_EP93XX_SOC_I2S_WATCHDOG',
#   'HAVE_ARCH_TRANSPARENT_HUGEPAGE_PUD',
#   'MTD_AFS_PARTS',
#   'USB_G_DBGP_SERIAL',
#   'PCI_GOANY',
#   'VEXPRESS_CONFIG',
#   'TRANSPARENT_HUGEPAGE_MADVISE',
#   'TI_SCI_PM_DOMAINS',
#   'IBMVETH',
#   'ARCH_HAS_PTE_SPECIAL',
#   'PINCTRL_COH901',
#   'IXP4XX_WATCHDOG',
#   'MCF8390',
#   'UCC_GETH',
#   'PINCTRL_IMX7ULP',
#   'DRM_ETNAVIV',
#   'CMT_SPEECH',
#   'DRM_OMAP_ENCODER_OPA362',
#   'X86',
#   'MFD_DAVINCI_VOICECODEC',
#   'HAVE_DYNAMIC_FTRACE_WITH_REGS',
#   'SCSI_SNI_53C710',
#   'BLK_DEV_SWIM',
#   'LOGO_SUPERH_MONO',
#   'NET_NETX',
#   'SPI_COLDFIRE_QSPI',
#   'SERIAL_PXA',
#   'EDAC_I82443BXGX',
#   'X86_PAE',
#   'SUNBMAC',
#   'QCOM_Q6V5_PAS',
#   'NE2000',
#   'ARM_GIC',
# ...
#   'SND_SOC_ZYLONITE',
#   'BLK_DEV_UMC8672',
#   'MODULES_TREE_LOOKUP',
#   'IRQ_DOMAIN',
#   'USB_EHCI_HCD_PPC_OF',
#   'CLKSRC_IMX_TPM',
#   'IUCV',
#   'FB_S3C2410',
#   'OCTEON_WDT',
#   'SCSI_LASI700',
#   'SERIO_RPCKBD',
#   'SND_AOA_TOONIE',
#   'KRAITCC',
#   'SOC_REALVIEW',
#   'IBM_EMAC_ZMII',
#   'CLKSRC_LPC32XX',
#   'PINCTRL_IMX8DXL',
#   'INLINE_WRITE_LOCK_IRQ',
#   'SND_EP93XX_SOC_I2S_WATCHDOG',
#   'HAVE_ARCH_TRANSPARENT_HUGEPAGE_PUD',
#   'MTD_AFS_PARTS',
#   'PM_SLEEP_SMP_NONZERO_CPU',
#   'PCI_GOANY',
#   'VEXPRESS_CONFIG',
#   'TRANSPARENT_HUGEPAGE_MADVISE',
#   'TI_SCI_PM_DOMAINS',
#   'IBMVETH',
#   'ARCH_HAS_PTE_SPECIAL',
#   'PINCTRL_COH901',
#   'IXP4XX_WATCHDOG',
#   'MCF8390',
#   'UCC_GETH',
#   'PINCTRL_IMX7ULP',
#   'CMT_SPEECH',
#   'X86',
#   'MFD_DAVINCI_VOICECODEC',
#   'HAVE_DYNAMIC_FTRACE_WITH_REGS',
#   'SCSI_SNI_53C710',
#   'BLK_DEV_SWIM',
#   'LOGO_SUPERH_MONO',
#   'SPI_COLDFIRE_QSPI',
#   'SERIAL_PXA',
#   'EDAC_I82443BXGX',
#   'X86_PAE',
#   'SUNBMAC',
#   'ARM_ARMADA_8K_CPUFREQ',
#   'QCOM_Q6V5_PAS',
#   'ARCH_STACKWALK',
#   'ARM_GIC',
#   'NE2000',
#   'X86_SPEEDSTEP_SMI',
#   'SND_PXA2XX_SOC_IMOTE2',
#   'MMC_QCOM_DML',
#   'ARM_GIC_V3_ITS_FSL_MC',
#   'INTERCONNECT_QCOM_BCM_VOTER',
#   'OF_NUMA',
#   'LEGACY_VSYSCALL_NONE',
#   'ARM_S3C2416_CPUFREQ',
#   'IDE_LEGACY',
#   'ARM_GIC_V3',
#   'KCSAN_VERBOSE',
#   'MVEBU_ICU',
#   'SERIAL_PIC32_CONSOLE',
#   'SUN50I_ERRATUM_UNKNOWN1',
#   'B43_BUSES_BCMA',
#   'SND_MIPS',
#   'TI_AM65_CPSW_TAS',
#   'SND_SOC_IMX_PCM_FIQ',
#   'HVC_OPAL',
#   'KEYBOARD_AMIGA',
#   'EDAC_PASEMI',
#   'PTP_1588_CLOCK_IXP46X',
#   'CPU_SUP_CYRIX_32',
#   'SND_SOC_IMX_SSI',
#   'SND_MMP_SOC_BROWNSTONE',
#   'SND_SOC_DB1200',
#   'PINCTRL_MESON_AXG',
#   'IOP_WATCHDOG',
#   'IMA_DEFAULT_HASH_SM3',
#   'BCMA_DRIVER_PCI_HOSTMODE',
#   'USB_S3C_HSUDC',
#   'NOKIA_MODEM',
#   'SND_SOC_MEDIATEK',
#   'POWER_RESET_XGENE',
#   'BACKLIGHT_EP93XX',
#   'ARM_TEGRA124_CPUFREQ',
#   'SPI_PL022',
#   'REGULATOR_TI_ABB',
#   'ARCH_INLINE_SPIN_UNLOCK',
#   'CLOCKSOURCE_WATCHDOG',
#   'DEBUG_NOMMU_REGIONS',
#   'ARCH_HAS_UACCESS_FLUSHCACHE',
#   'LOONGSON_HTPIC',
#   'OMAP2_DSS_DSI',
#   'USB_S3C2410',
#   'ARCH_INLINE_SPIN_UNLOCK_IRQRESTORE',
#   'HOTPLUG_PCI_RPA_DLPAR',
#   'I2C_CADENCE',
#   'SERIO_SA1111',
#   'SND_SH7760_AC97',
#   'HAVE_FUNCTION_ARG_ACCESS_API',
#   'TOUCHSCREEN_WM97XX_MAINSTONE',
#   'SND_SOC_PHYCORE_AC97',
#   'SNI_82596',
#   'AHCI_OCTEON',
#   'MMC_AU1X',
#   'MOUSE_PS2_OLPC',
#   'ARCH_INLINE_SPIN_LOCK_BH',
#   'ZSWAP_ZPOOL_DEFAULT_ZSMALLOC',
#   'ARCH_R8A7792',
#   'JOYSTICK_AMIGA',
#   'SND_SOC_TXX9ACLC_GENERIC',
#   'FB_OLPC_DCON',
#   'WINDFARM_PM91',
#   'BERLIN2_ADC',
#   'KEYBOARD_HIL_OLD',
#   'ORION_IRQCHIP',
#   'LOGO_MAC_CLUT224',
#   'ARM_SCPI_CPUFREQ',
#   'STACKTRACE_SUPPORT',
#   'MTD_NAND_FSL_UPM',
#   'SND_ATMEL_AC97C',
#   '3C515',
#   'FAULT_INJECTION_STACKTRACE_FILTER',
#   'AGP_HP_ZX1',
#   'RTC_DRV_PUV3',
#   'SND_SOC_AU1XI2SC',
#   'MODULE_SIG_SHA384',
#   'PINCTRL_SUN5I',
#   'GENERIC_IDLE_POLL_SETUP',
#   'VM86',
#   'IBM_EMAC_RGMII',
#   'MTD_NAND_PASEMI',
#   'I2C_XGENE_SLIMPRO',
#   'TEGRA_MC',
#   'OSF4_COMPAT',
#   'I2C_ACORN',
#   'SERIAL_8250_MT6577',
#   'FB_ARMCLCD',
#   'RC32434_WDT',
#   'PNPBIOS_PROC_FS',
#   'TEST_ASYNC_DRIVER_PROBE',
#   'MCP_SA11X0',
#   'SND_PXA2XX_SOC_TOSA',
#   'ARCH_SUPPORTS_UPROBES',
#   'ARCH_RCAR_GEN1',
#   'SND_PXA2XX_SOC_AC97',
#   'GREYBUS_CAMERA',
#   'CLK_IMX8MN',
#   'CLKSRC_EFM32',
#   'HAVE_ARCH_KASAN',
#   'SND_PPC',
#   'LOCK_DOWN_KERNEL_FORCE_CONFIDENTIALITY',
#   'PMAC_RACKMETER',
#   'DCACHE_WORD_ACCESS',
#   'LOONGSON1_WDT',
#   'GENERIC_VDSO_32',
#   'ARMADA_CP110_SYSCON',
#   'ARCH_HAS_FILTER_PGPROT',
#   'GENERIC_CALIBRATE_DELAY',
#   'RTC_DRV_LOONGSON1',
#   'MTD_VMU',
#   'PREEMPT_RCU',
#   'LEGACY_VSYSCALL_EMULATE',
#   'PHY_MVEBU_CP110_COMPHY',
#   'SND_SOC_MPC5200_AC97',
#   'HAVE_FB_ATMEL',
#   'WIZNET_BUS_DIRECT',
#   'PCI_MT7621',
#   'SCSI_ZALON',
#   'USB_PXA25X_SMALL',
#   'CLOCKSOURCE_VALIDATE_LAST_CYCLE',
#   'GENERIC_IRQ_MULTI_HANDLER',
#   'PINCTRL_MESON_A1',
#   'AUDIT_GENERIC',
#   'DASD_FBA',
#   'X86_INTEL_TSX_MODE_AUTO',
#   'CC_HAS_ASM_GOTO_OUTPUT',
#   'ARCH_HAS_SYSCALL_WRAPPER',
#   'SND_SOC_UX500_MACH_MOP500',
#   'SERIAL_TXX9_STDSERIAL',
#   'MOUSE_LOGIBM',
#   'ARCH_R8A77965',
#   'PINCTRL_IMX51',
#   'SENSORS_AB8500',
#   'SND_SOC_DM365_VOICE_CODEC',
#   'ADB_PMU_LED_DISK',
#   'PCI_MT7621_PHY',
#   'MVEBU_DEVBUS',
#   'ODD_RT_SIGACTION',
#   'ST_SLIM_REMOTEPROC',
#   'DA8XX_MSTPRI',
#   'SND_SOC_SH4_SSI',
#   'DRM_MSM_DSI_28NM_PHY',
#   'REGULATOR_QCOM_RPM',
#   'PHY_EXYNOS5250_SATA',
#   'QCOM_CLK_RPM',
#   'PCI_SYSCALL',
#   'DRM_ARMADA',
#   'WATCHDOG_CP1XXX',
#   'MPENTIUMIII',
#   'AB8500_BM',
#   'MAC_SCSI',
#   'EFI_PCDP',
#   'SND_PXA910_SOC',
#   'BATTERY_TOSA',
#   'CRC32_SARWATE',
#   'PINCTRL_SUN8I_A33',
#   'ANSLCD',
#   'SPI_LOOPBACK_TEST',
#   'EDAC_HIGHBANK_MC',
#   'TCIC',
#   'FSL_BMAN_TEST',
#   'ARM_ETHER3',
#   'SCSI_IBMVSCSIS',
#   'GOOGLE_COREBOOT_TABLE_ACPI',
#   'HAVE_KPROBES',
#   'NOHIGHMEM',
#   'SND_AOA_FABRIC_LAYOUT',
#   'DMASOUND_ATARI',
#   'ARCH_HAS_KCOV',
#   'ARM_S3C_CPUFREQ',
#   'SND_AICA',
#   'ARCH_WANT_BATCHED_UNMAP_TLB_FLUSH',
#   'MMC_SDHCI_ST',
#   'PHY_MIPHY28LP',
#   'HISILICON_IRQ_MBIGEN',
#   'STE_DMA40',
#   'LOGO_SUN_CLUT224',
#   'GPIO_IXP4XX',
#   'MFD_ASIC3',
#   'PINCTRL_AT91',
#   'COMMON_CLK_MESON8B',
#   'GENERIC_SMP_IDLE_THREAD',
#   'WINDFARM_PM72',
#   'X86_ESPFIX32',
#   'EDAC_ALTERA_SDRAM',
#   'CRYPTO_DEV_FSL_CAAM_AHASH_API',
#   'WIZNET_BUS_INDIRECT',
#   'FB_PXA_OVERLAY',
#   'FB_AMIGA_ECS',
#   'SAMPLE_QMI_CLIENT',
#   'COMMON_CLK_STM32F',
#   'SERIAL_SB1250_DUART_CONSOLE',
#   'COMMON_CLK_MESON_AO_CLKC',
#   'SRAM_EXEC',
#   'MODULE_REL_CRCS',
#   'HAVE_EISA',
#   'CLKSRC_EXYNOS_MCT',
#   'INDYDOG',
#   'SPI_ATMEL_QUADSPI',
#   'ADB_MACII',
#   'AUDIT_ARCH',
#   'PROFILE_ALL_BRANCHES',
#   'IMX_GPCV2',
#   'ARCH_CLOCKSOURCE_DATA',
#   'BUILDTIME_TABLE_SORT',
#   'VFIO_PCI_NVLINK2',
#   'LOCK_DEBUGGING_SUPPORT',
#   'CPU_FREQ_CBE',
#   'AMX3_PM',
#   'CLPS711X_IRQCHIP',
#   'ARM_ZYNQ_CPUIDLE',
#   'ZYNQMP_IPI_MBOX',
#   'PCIEASPM_PERFORMANCE',
#   'SERIAL_IP22_ZILOG',
#   'HW_RANDOM_MXC_RNGA',
#   'ARCH_INLINE_READ_LOCK',
#   'OMAP_DSS_BASE',
#   'TN3270_FS',
#   'CMA_SIZE_SEL_MIN',
#   'ARM_KIRKWOOD_CPUIDLE',
#   'SCSI_IBMVFC',
#   'MMC_S3C',
#   'NVMEM_SUNXI_SID',
#   'CPU_SUP_TRANSMETA_32',
#   'AB8500_CORE',
#   'VFIO_PLATFORM',
#   'ARCH_WANT_HUGE_PMD_SHARE',
#   'DEBUG_IMR_SELFTEST',
#   'FS_ENET',
#   'MGEODEGX1',
#   'MCORE2',
#   'DMA_SUN4I',
#   'CRYPTO_CRCT10DIF_VPMSUM',
#   'B43_BUSES_SSB',
#   'SCTP_DEFAULT_COOKIE_HMAC_NONE',
#   'HAVE_ATOMIC_IOMAP',
#   'ARCH_SUPPORTS_NUMA_BALANCING',
#   'BLK_DEV_IDE_PMAC_ATA100FIRST',
#   'CRYPTO_DEV_QCE_ENABLE_SKCIPHER',
#   'MTD_CFI_FLAGADM',
#   'NO_GENERIC_PCI_IOPORT_MAP',
#   'USB_TI_CPPI_DMA',
#   'PHY_QCOM_IPQ806X_SATA',
#   'MMC_WMT',
#   'HANDLE_DOMAIN_IRQ',
#   'TOUCHSCREEN_LPC32XX',
#   'SPEAKUP_SYNTH_DECPC',
#   'INPUT_IXP4XX_BEEPER',
#   'ARCH_HAS_ADD_PAGES',
#   'IPMI_POWERNV',
#   'AT91_ADC',
#   'ARCH_R8A77961',
#   'SND_AOA_TAS',
#   'AMBA_PL08X',
#   'INPUT_SGI_BTNS',
#   'ARM_GIC_V2M',
#   'PINCTRL_IMX35',
#   'HZ_100',
#   'OF_DMA_DEFAULT_COHERENT',
#   'LEDS_LOCOMO',
#   'PINCTRL_RT2880',
#   'SERIAL_ICOM',
#   'OMAP_SSI',
#   'DRM_MSM_GPU_SUDO',
#   'CC_HAS_STACKPROTECTOR_NONE',
#   'PINCTRL_SUN4I_A10',
#   'MIPS_PLATFORM_DEVICES',
#   'INTERCONNECT_QCOM_MSM8974',
#   'INLINE_WRITE_TRYLOCK',
#   'DMA_NONCOHERENT_MMAP',
#   'SND_SOC_SAMSUNG_RX1950_UDA1380',
#   'ZONE_DMA32',
#   'PERCPU_TEST',
#   'ARCH_TEGRA_2x_SOC',
#   'PNPBIOS',
#   'X86_REBOOTFIXUPS',
#   'MIXCOMWD',
#   'QCOM_WCNSS_PIL',
#   'SCSI_SUNESP',
#   'SCSI_FDOMAIN_ISA',
#   'MTD_NAND_S3C2410_DEBUG',
#   'SAMPLE_HW_BREAKPOINT',
#   'ARM_SPE_PMU',
#   'IBMVNIC',
#   'AGP_UNINORTH',
#   'TEGRA_BPMP_THERMAL',
#   'ARM_BIG_LITTLE_CPUIDLE',
#   'POWER_RESET_AXXIA',
#   'FB_I810_GTF',
#   'LOONGSON_HTVEC',
#   'TI_PWMSS',
#   'FTMAC100',
#   'ST_THERMAL_SYSCFG',
#   'ARMADA_XP_CLK',
#   'EDAC_ALTERA_SDMMC',
#   'MAC8390',
#   'DA8XX_DDRCTL',
#   'SELECT_MEMORY_MODEL',
#   'SND_SOC_UX500_PLAT_DMA',
#   'FB_Q40',
#   'IO_DELAY_NONE',
#   'THREAD_INFO_IN_TASK',
#   'XGENE_SLIMPRO_MBOX',
#   'RTC_DRV_TWL92330',
#   'TI_KEYSTONE_NETCP',
#   'FB_BW2',
#   'BINFMT_FLAT_OLD_ALWAYS_RAM',
#   'SND_SOC_AU1XPSC_AC97',
#   'ST_REMOTEPROC',
#   'MVEBU_CLK_CPU',
#   'ARM_S3C2440_CPUFREQ',
#   'DRM_HDLCD',
#   'DRM_MALI_DISPLAY',
#   'USB_FUSB300',
#   'HMC_DRV',
#   'MMC_MESON_GX',
#   'RELR',
#   'GENERIC_IRQ_MATRIX_ALLOCATOR',
#   'R3964',
#   'TEGRA30_EMC',
#   'THERM_WINDTUNNEL',
#   'MX3_IPU',
#   'ULTRA',
#   'FB_S3C2410_DEBUG',
#   'MOUSE_PC110PAD',
#   'PINCTRL_SPEAR3XX',
#   'ARCH_HAS_DMA_COHERENCE_H',
#   'MMC_SDHCI_SPRD',
#   'KEYSTONE_TIMER',
#   'GPIO_VF610',
#   'MCSAFE_TEST',
#   'GENERIC_IOREMAP',
#   'HAVE_OPROFILE',
#   'DEFAULT_SFQ',
#   'USB_OHCI_HCD_OMAP1',
#   'HAVE_STACKPROTECTOR',
#   'GENERIC_IRQ_IPI',
#   'OCXL',
#   'LEDS_FSG',
#   'OMPIC',
#   'LANTIQ_WDT',
#   'RASPBERRYPI_POWER',
#   'CLKSRC_NPS',
#   'CLONE_BACKWARDS3',
#   'SND_SOC_AU1XAUDIO',
#   'ARCH_FLATMEM_ENABLE',
#   'CPU_FREQ_DEFAULT_GOV_USERSPACE',
#   'HAVE_ARM_SMCCC_DISCOVERY',
#   'RTC_DRV_RS5C313',
#   'MMC_TMIO',
#   'DRM_OMAP_PANEL_DSI_CM',
#   'USB_TI_CPPI41_DMA',
#   'PINCTRL_GEMINI',
#   'ARCH_HAS_DMA_SET_UNCACHED',
#   'INLINE_WRITE_LOCK_IRQSAVE',
#   'ARMADA_AP_CP_HELPER',
#   'OR1K_PIC',
#   'RTL8192U',
#   'LTE_GDM724X',
#   'ARM_S3C24XX_CPUFREQ_IODEBUG',
#   'HAVE_ARCH_KASAN_VMALLOC',
#   'MFD_T7L66XB',
#   'ARCH_TEGRA_3x_SOC',
#   'SND_AOA_SOUNDBUS_I2S',
#   'POWER_RESET_AT91_POWEROFF',
#   'PCI_DOMAINS_GENERIC',
#   'ARM_KIRKWOOD_CPUFREQ',
#   'TEST_VMALLOC',
#   'VIRT_CPU_ACCOUNTING',
#   'GENERIC_CPU_VULNERABILITIES',
#   'VIRT_CPU_ACCOUNTING_NATIVE',
#   'ARM_SCMI_CPUFREQ',
#   'NWBUTTON',
#   'XILINX_INTC',
#   'DAVINCI_CP_INTC',
#   'X86_INTEL_USERCOPY',
#   'DT_IDLE_STATES',
#   'PINCTRL_IMX8QM',
#   'MENELAUS',
#   'PINCTRL_SUN8I_A23',
#   'VMCP',
#   'MTD_LANTIQ',
#   'EDAC_BLUEFIELD',
#   'SERIAL_MCF',
#   'PHY_RCAR_GEN2',
#   'SERIAL_PMACZILOG_CONSOLE',
#   'DRM_RCAR_VSP',
#   'ARCH_R8A7743',
#   'HAS_IOPORT_MAP',
#   'ARM_QCOM_CPUFREQ_NVMEM',
#   'CSKY_MP_TIMER',
#   'FB_I810',
#   'CRYPTO_DEV_UX500_DEBUG',
#   'FB_MBX_DEBUG',
#   'CAN_RCAR',
#   'ELAN_CPUFREQ',
#   'CRYPTO_MD5_PPC',
#   'ACPI_PPTT',
#   'BINFMT_FLAT_ARGVP_ENVP_ON_STACK',
#   'HW_RANDOM_OMAP',
#   'SGI_NEWPORT_CONSOLE',
#   'PCMCIA_MAX1600',
#   'ZX2967_WATCHDOG',
#   'EP93XX_ADC',
#   'MTD_NAND_FSL_ELBC',
#   'KEYBOARD_SPEAR',
#   'INLINE_READ_UNLOCK_IRQRESTORE',
#   'DMASCC',
#   'PINCTRL_IMX_SCU',
#   'TEST_USER_COPY',
#   'PINCTRL_PISTACHIO',
#   'EEPROM_DIGSY_MTC_CFG',
#   'RTC_DRV_SIRFSOC',
#   'TEST_STATIC_KEYS',
#   'KORINA',
#   'SYSCTL_ARCH_UNALIGN_NO_WARN',
#   'PCMCIA_SA1100',
#   'CPU_FREQ_DEFAULT_GOV_ONDEMAND',
#   'SERIAL_MESON',
#   'WINDFARM_PM112',
#   'SH_CPU_FREQ',
#   'PIC32_EVIC',
#   'SND_SOC_POWERPC_DMA',
#   'HAVE_KERNEL_BZIP2',
#   'ARCH_HAS_MEMREMAP_COMPAT_ALIGN',
#   'ARCH_INLINE_WRITE_LOCK_IRQ',
#   'TEGRA_IOMMU_GART',
#   'GPIO_OCTEON',
#   'PATA_FALCON',
#   'SND_SOC_SAMSUNG_NEO1973_WM8753',
#   'MESON_SECURE_PM_DOMAINS',
#   'GPIO_MM_LANTIQ',
#   'CRYPTO_ACOMP',
#   'ARCH_USE_CMPXCHG_LOCKREF',
#   'SND_PXA2XX_SOC_E800',
#   'X86_INTEL_QUARK',
#   'PCMCIA_AHA152X',
#   'ARCH_WEAK_RELEASE_ACQUIRE',
#   'STI_RESET_SYSCFG',
#   'THERMAL_DEFAULT_GOV_POWER_ALLOCATOR',
#   'RTC_MC146818_LIB',
#   'ATARI_KBD_CORE',
#   'M586TSC',
#   'WDT_MTX1',
#   'MFD_TC6387XB',
#   'ARCH_ENABLE_MEMORY_HOTPLUG',
#   'SERIAL_21285_CONSOLE',
#   'SCSI_ARXESCSI',
#   'MFD_DB8500_PRCMU',
#   'TEST_BPF',
#   'FB_VALKYRIE',
#   'ZYNQMP_FIRMWARE_DEBUG',
#   'KASAN',
#   'CRYPTO_DEV_FSL_CAAM_JR',
#   'XPS_USB_HCD_XILINX',
#   'VERSATILE_FPGA_IRQ',
#   'ARM_SPEAR_CPUFREQ',
#   'HAVE_RAPIDIO',
#   'USB_PXA25X',
#   'HYDRA',
#   'DISCONTIGMEM',
#   'MAC89x0',
#   'CAN_LEDS',
#   'NVDIMM_TEST_BUILD',
#   'TEGRA_HOST1X',
#   'X86_ANCIENT_MCE',
#   'HAVE_IRQ_EXIT_ON_IRQ_STACK',
#   'DRM_SUN4I_HDMI_CEC',
#   'BVME6000_SCSI',
#   'COMMON_CLK_MESON_DUALDIV',
#   'DRM_SHMOBILE',
#   'WATCHDOG_RTAS',
#   'AUTO_IRQ_AFFINITY',
#   'I2C_PXA_PCI',
#   'PMAC_MEDIABAY',
#   'CPU_PM',
#   'VMLOGRDR',
#   'TI_SCI_CLK_PROBE_FROM_FW',
#   'INTERCONNECT_QCOM_SC7180',
#   'RTC_LIB',
#   'ARM_IMX8M_DDRC_DEVFREQ',
#   'M586MMX',
#   'STRICT_KERNEL_RWX',
#   'ARM_CCN',
#   'HAVE_KERNEL_LZ4',
#   'PREEMPTION',
#   'HW_RANDOM_XGENE',
#   'GENERIC_EARLY_IOREMAP',
#   'CRYPTO_SHA1_OCTEON',
#   'S390_VMUR',
#   'ARCH_HAS_SET_DIRECT_MAP',
#   'HAVE_KCSAN_COMPILER',
#   'TS_NBUS',
#   'AFIUCV',
#   'PCI_RCAR_GEN2',
#   'I2C_PASEMI',
#   'VMSPLIT_2G_OPT',
#   'SND_ATMEL_SOC_TSE850_PCM5142',
#   'X86_BIGSMP',
#   'BMAC',
#   'ARCH_INLINE_READ_LOCK_IRQSAVE',
#   'BINFMT_SHARED_FLAT',
#   'PINCTRL_TEGRA194',
#   'SPI_QCOM_QSPI',
#   'SUNVDC',
#   'CRYPTO_DEV_GEODE',
#   'ARCH_WANT_NUMA_VARIABLE_LOCALITY',
#   'CRYPTO_DEV_NX_COMPRESS_POWERNV',
#   'HAVE_ARCH_HUGE_VMAP',
#   'GPIO_ALTERA_A10SR',
#   'SERIAL_SA1100',
#   'HW_RANDOM_BCM2835',
#   'GPIO_VR41XX',
#   'DRM_MESON',
#   'AHCI_ST',
#   'SND_SOC_MT2701_CS42448',
#   'INSTRUCTION_DECODER',
#   'MINIX_FS_NATIVE_ENDIAN',
#   'SND_SUN_DBRI',
#   'SPI_AU1550',
#   'QCOM_IPA',
#   'SCSI_ZORRO_ESP',
#   'SND_HDA_ALIGNED_MMIO',
#   'ROCKCHIP_TIMER',
#   'GUP_GET_PTE_LOW_HIGH',
#   'TWL4030_USB',
#   'PCI_KEYSTONE_HOST',
#   'TC35815',
#   'CRYPTO_SHA512_OCTEON',
#   'SERIAL_PIC32',
#   'MTD_MS02NV',
#   'BLK_DEV_MAC_IDE',
#   'ARCH_SUPPORTS_DEBUG_PAGEALLOC',
#   'SND_PXA2XX_AC97',
#   'HAVE_EBPF_JIT',
#   'FSL_ERRATUM_A008585',
#   'FB_G364',
#   'X86_IO_APIC',
#   'OLD_SIGSUSPEND',
#   'MMC_SDHCI_ESDHC_MCF',
#   'IRQ_PREFLOW_FASTEOI',
#   'DRM_ATMEL_HLCDC',
#   'HIGHMEM64G',
#   'I2C_MPC',
#   'HW_RANDOM_OPTEE',
#   'X86_32_IRIS',
#   'GENERIC_LIB_LSHRDI3',
#   'ROCKCHIP_DW_MIPI_DSI',
#   'OMAP_DM_TIMER',
#   'CLKSRC_ARM_GLOBAL_TIMER_SCHED_CLOCK',
#   'DRM_MESON_DW_HDMI',
#   'INITRAMFS_COMPRESSION_BZIP2',
#   'SND_SOC_TXX9ACLC_AC97',
#   'RT2X00_LIB_SOC',
#   'SAMPLE_LIVEPATCH',
#   'ORION_WATCHDOG',
#   'CRYPTO_SERPENT_SSE2_586',
#   'PINCTRL_MESON_GXL',
#   'KEYBOARD_TEGRA',
#   'DEFAULT_CODEL',
#   'ARCH_HAS_TICK_BROADCAST',
#   'ISA',
#   'TN3270_TTY',
#   'CRYPTO_CRC32_S390',
#   'SND_SOC_MT8173_MAX98090',
#   'DRM_STM',
#   'LS_SCFG_MSI',
#   'TWL6030_USB',
#   'ARCH_OPTIONAL_KERNEL_RWX_DEFAULT',
#   'CCWGROUP',
#   'ARCH_HAS_CACHE_LINE_SIZE',
#   'POWERNV_OP_PANEL',
#   'COMMON_CLK_MESON_EE_CLKC',
#   'HAVE_DEBUG_KMEMLEAK',
#   'OMAP2_VRFB',
#   'ARM_PSCI_CHECKER',
#   'SENSORS_AMS_PMU',
#   'SND_GSC',
#   'USB_UHCI_BIG_ENDIAN_DESC',
#   'MMIOTRACE_TEST',
#   'HW_RANDOM_PIC32',
#   'MOUSE_ATIXL',
#   'HZ_250',
#   'MVME147_NET',
#   'IMA_DEFAULT_HASH_SHA512',
#   'CLKSRC_I8253',
#   'MMC_SDHCI_CNS3XXX',
#   'ISP1301_OMAP',
#   'LCD_HP700',
#   'RTC_DRV_DS17285',
#   'POWERNV_CPUIDLE',
#   'X86_LONGRUN',
#   'LOGO_SGI_CLUT224',
#   'GCC_PLUGIN_ARM_SSP_PER_TASK',
#   'IMX_REMOTEPROC',
#   'BLK_DEV_CY82C693',
#   'PINCTRL_DIGICOLOR',
#   'PINCTRL_IMX8MQ',
#   'PINCTRL_IMX7D',
#   'FB_HIT',
#   'PKEY',
#   'OMAP2_DSS_DEBUGFS',
#   'TOOLS_SUPPORT_RELR',
#   'CC_HAS_WORKING_NOSANITIZE_ADDRESS',
#   'CHARLCD_BL_OFF',
#   'A2091_SCSI',
#   'QCOM_BAM_DMA',
#   'MMC_SDHCI_ESDHC_IMX',
#   'SERIAL_8250_FSL',
#   'INTERCONNECT_QCOM_RPMH',
#   'KCSAN_SKIP_WATCH_RANDOMIZE',
#   'ARCH_WANT_DEFAULT_TOPDOWN_MMAP_LAYOUT',
#   'SERIAL_8250_EXAR_ST16C554',
#   'LEDS_NET48XX',
#   'TI_K3_UDMA_GLUE_LAYER',
#   'HVC_RTAS',
#   'MTD_PHYSMAP_IXP4XX',
#   'PHY_MVEBU_SATA',
#   'MODULE_COMPRESS_XZ',
#   'CLK_IMX8MP',
#   'AGP_I460',
#   'EXYNOS_PMU_ARM_DRIVERS',
#   'GENERIC_ARCH_TOPOLOGY',
#   'RTC_DRV_STARFIRE',
#   'EDAC_OCTEON_PCI',
#   'STI_CONSOLE',
#   'SERIO_NVEC_PS2',
#   'SND_SOC_IMX_MC13783',
#   'FB_PXA',
#   'PIC32_DMT',
#   'MTD_LPDDR2_NVM',
#   'SSB_POSSIBLE',
#   'NO_HZ_FULL',
#   'NET_VENDOR_PASEMI',
#   'HAVE_FUNCTION_GRAPH_TRACER',
#   'SATA_AHCI_SEATTLE',
#   'WD80x3',
#   'PINCTRL_NOMADIK',
#   'MPENTIUMII',
#   'INITRAMFS_COMPRESSION_LZ4',
#   'WINDFARM_PM121',
#   'CRYPTO_AES_SPARC64',
#   'USB_OHCI_LITTLE_ENDIAN',
#   'INIT_STACK_ALL',
#   'SMC911X',
#   'POWER_RESET_AT91_RESET',
#   'FB_PXA_SMARTPANEL',
#   'USB_OHCI_HCD_PPC_OF_LE',
#   'ARM_SMMU_V3_PMU',
#   'MMC_DW_ROCKCHIP',
#   'ATH5K_AHB',
#   'ARCH_HAS_UBSAN_SANITIZE_ALL',
#   'CLK_VEXPRESS_OSC',
#   'ARCH_WANT_IPC_PARSE_VERSION',
#   'BLK_DEV_CS5536',
#   'SOC_INTEGRATOR_CM',
#   'GENERIC_IRQ_SHOW',
#   'TRACE_PREEMPT_TOGGLE',
#   'STM32_EXTI',
#   'MVEBU_CLK_COMMON',
#   'FB_MX3',
#   'MK7',
#   'MOUSE_INPORT',
#   'X86_GX_SUSPMOD',
#   'FSL_QMAN_TEST',
#   'SND_EP93XX_SOC_I2S',
#   'DMA_REMAP',
#   'ARCH_INLINE_READ_UNLOCK_IRQRESTORE',
#   'CLKSRC_TI_32K',
#   'ARCH_SELECT_MEMORY_MODEL',
#   'SERIAL_SB1250_DUART',
#   'BRANCH_TRACER',
#   'KEYBOARD_NVEC',
#   'SND_POWERMAC_AUTO_DRC',
#   'TN3215_CONSOLE',
#   'CPU_FREQ_MAPLE',
#   'MODULE_SIG_SHA256',
#   'ROCKCHIP_LVDS',
#   'OF_PROMTREE',
#   'ARCH_WANTS_DYNAMIC_TASK_STRUCT',
#   'MMU',
#   'FSL_HV_MANAGER',
#   'EDAC_QCOM',
#   'SAMPLE_TRACE_EVENTS',
#   'SGI_MFD_IOC3',
#   'ACPI_MCFG',
#   'SCSI_NSP32',
#   'DRM_MSM_DSI_20NM_PHY',
#   'PINCTRL_XWAY',
#   'MOUSE_MAPLE',
#   'TOUCHSCREEN_HTCPEN',
#   'KEXEC_ELF',
#   'RTC_DRV_PXA',
#   'PL353_SMC',
#   ...]}

# %%
{
    version: ("CC_OPTIMIZE_FOR_SIZE" in Dataset(version).get_dataframe(Columns.options, group_collinear_options=False).columns)
    for version in get_config()["report"]["versions"]
}
# Out:
# {413: True, 415: True, 420: True, 500: True, 504: True, 507: True, 508: True}

# %%
df["CC_OPTIMIZE_FOR_SIZE"]
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 92557     True
# 92558     True
# 92559     True
# 92560     True
# 92561     True
# Name: CC_OPTIMIZE_FOR_SIZE, Length: 92562, dtype: bool

# %%
df = Dataset(508).get_dataframe(Columns.targets)

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series
